# %% [markdown]
# # HKTDC control — Hermes
#
# This isolated version uses repository-relative paths and a public SSR data contract. It selects only rows with a nonblank `prefix` starting in 3, 7, 10, 14, or 30 days. Results are written beneath `Result/Exhibition Organizers/HKTDC-hermes/`.

# %%
from pathlib import Path
import subprocess, sys

repo_root = Path.cwd()
script = repo_root / 'PY' / 'Event Organizer-hermes' / 'hktdc_control-hermes.py'
subprocess.run([sys.executable, str(script)], check=True)

# %% [markdown]
# For a public Google Sheets CSV export, add `--control-csv-url <published-csv-url>` to the command after the owner provides the link.
