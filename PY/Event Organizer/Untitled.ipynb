# %%
import pandas as pd

# %%
with open('/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/messe_frankfurt_control.json', 'r') as file:
    data = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open('/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/messe_frankfurt_control.json', 'r') as file:
# ----> 2     data = json.load(file)
#
# File /opt/anaconda3/envs/playwright_env/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...

# %%
df = pd.read_json('/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/messe_frankfurt_control.json', lines=True,encoding='utf-8')

# %%
df.to_csv('/Users/rowena/Other Projects/external_data_study/Result/Event Organizer/messe_frankfurt_control.csv')
# Out:
#                                            Event Title           Event Date  \
# 0           SPS – Smart Production Solutions Guangzhou     04.–06.March2026
# 1                                      Asiamold Select     04.–06.March2026
# 2                                Salon du Chocolat USA     07.–08.March2026
# 3                                     Light + Building     08.–13.March2026
# 4    Intertextile Shanghai Home Textiles - Spring E...     11.–13.March2026
# ..                                                 ...                  ...
# 229                             Automechanika Shanghai  02.–05.December2027
# 230                                         Texprocess     04.–07.April2028
# 231                                         Techtextil     04.–07.April2028
# 232                                               IFFA       13.–18.May2028
# 233                              Texcare International  08.–11.November2028
#
#           Event City Event Country  \
# ...
