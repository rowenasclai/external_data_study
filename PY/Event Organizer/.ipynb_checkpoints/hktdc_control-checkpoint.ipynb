# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/rowena/Other Projects/external_data_study/Result/Exhibition Organizers/HKTDC/Event_Schedule/event_control.csv')

# %%
today = pd.Timestamp.now().normalize()  # .normalize() sets time to 00:00:00
start_day = today + pd.Timedelta(days=30)
week_t2 = today + pd.Timedelta(days=14)
day_10 = today + pd.Timedelta(days=10)
week_1 = today + pd.Timedelta(days=7)
day_3 = today + pd.Timedelta(days=3)

df['event_start_date'] = pd.to_datetime(df['event_start_date'])

df[((df['event_start_date']< start_day) | (df['event_start_date']== week_t2) |(df['event_start_date']== day_10) |(df['event_start_date']==week_1) |(df['event_start_date']==day_3)) & (df['event_start_date'] > today)]
# Out:
#                                           event_title  \
# 46  HKTDC Hong Kong Electronics Fair (Autumn Editi...
# 47                        electronicAsia 2026 (HKCEC)
#
#                                           event_url        event_date  \
# 46  https://www.hktdc.com/event/hkelectronicsfairae  13 - 16 Oct 2026
# 47       https://www.hktdc.com/event/electronicasia  13 - 16 Oct 2026
#
#    event_format event_location event_start_date event_end_date  \
# 46   Exhibition      Hong Kong       2026-10-13  10/16/26 0:00
# 47   Exhibition      Hong Kong       2026-10-13  10/16/26 0:00
#
#    last_process_date               prefix
# 46               NaN  hkelectronicsfairae
# 47               NaN       electronicasia

# %%
tmp=df[((df['event_start_date']< start_day) | (df['event_start_date']== week_t2) |(df['event_start_date']== day_10) |(df['event_start_date']==week_1) |(df['event_start_date']==day_3)) & (df['event_start_date'] > today)]

# %%
tmp
# Out:
#                                           event_title  \
# 46  HKTDC Hong Kong Electronics Fair (Autumn Editi...
# 47                        electronicAsia 2026 (HKCEC)
#
#                                           event_url        event_date  \
# 46  https://www.hktdc.com/event/hkelectronicsfairae  13 - 16 Oct 2026
# 47       https://www.hktdc.com/event/electronicasia  13 - 16 Oct 2026
#
#    event_format event_location event_start_date event_end_date  \
# 46   Exhibition      Hong Kong       2026-10-13  10/16/26 0:00
# 47   Exhibition      Hong Kong       2026-10-13  10/16/26 0:00
#
#    last_process_date               prefix
# 46               NaN  hkelectronicsfairae
# 47               NaN       electronicasia

# %%
list(tmp['prefix'])
# Out:
# ['hkelectronicsfairae', 'electronicasia']

# %%
import subprocess

#all_events=['hkelectronicsfairae']

all_events=list(tmp['prefix'])
# The text input you want to send into the Python script

for t in all_events:
#my_text_input = "hello from the parent process"

# Execute the python script as a subprocess
    result_l1 = subprocess.run(
        ["python3", "/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/hktdc_exhibit_L1.py"],
        input=t,
        text=True,
        capture_output=True
    )

    if result_l1.returncode != 0:
        print(f"❌ L1 執行失敗！錯誤訊息如下：\n{result_l1.stderr}")
        break # 失敗就先停止，方便排查
    else:
        print(f"✅ L1 執行成功。標準輸出：\n{result_l1.stdout}")
    
    result_l2 = subprocess.run(
        ["python3", "/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/hktdc_exhibit_L2.py"],
        input=t,
        text=True,
        capture_output=True
    )

    if result_l2.returncode != 0:
        print(f"❌ L2 執行失敗！錯誤訊息如下：\n{result_l2.stderr}")
        break # 失敗就先停止，方便排查
    else:
        print(f"✅ L2 執行成功。標準輸出：\n{result_l2.stdout}")
    
    result_l3 = subprocess.run(
        ["python3", "/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/hktdc_exhibit_L3.py"],
        input=t,
        text=True,
        capture_output=True
    )

    if result_l3.returncode != 0:
        print(f"❌ L3 執行失敗！錯誤訊息如下：\n{result_l3.stderr}")
        break # 失敗就先停止，方便排查
    else:
        print(f"✅ L3 執行成功。標準輸出：\n{result_l3.stdout}")

    result_format = subprocess.run(
        ["python3", "/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/hktdc_format.py"],
        input=t,
        text=True,
        capture_output=True
    )
# Out:
# ✅ L1 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 - 50 out of 1449
# Processing 1 - 49 out of 1449
# Processing 51 - 99 out of 1449
# Processing 101 - 149 out of 1449
# Processing 151 - 199 out of 1449
# Processing 201 - 249 out of 1449
# Processing 251 - 299 out of 1449
# Processing 301 - 349 out of 1449
# Processing 351 - 399 out of 1449
# Processing 401 - 449 out of 1449
# Processing 451 - 499 out of 1449
# Processing 501 - 549 out of 1449
# Processing 551 - 599 out of 1449
# Processing 601 - 649 out of 1449
# Processing 651 - 699 out of 1449
# Processing 701 - 749 out of 1449
# Processing 751 - 799 out of 1449
# Processing 801 - 849 out of 1449
# Processing 851 - 899 out of 1449
# Processing 901 - 949 out of 1449
# Processing 951 - 999 out of 1449
# Processing 1001 - 1049 out of 1449
# Processing 1051 - 1099 out of 1449
# Processing 1101 - 1149 out of 1449
# Processing 1151 - 1199 out of 1449
# Processing 1201 - 1249 out of 1449
# Processing 1251 - 1299 out of 1449
# Processing 1301 - 1349 out of 1449
# Processing 1351 - 1399 out of 1449
# Processing 1401 - 1449 out of 1449
#
# ✅ L2 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 to 21 out of 1449
# Processing 21 to 41 out of 1449
# Processing 41 to 61 out of 1449
# Processing 61 to 81 out of 1449
# Processing 81 to 101 out of 1449
# Processing 101 to 121 out of 1449
# Processing 121 to 141 out of 1449
# Processing 141 to 161 out of 1449
# Processing 161 to 181 out of 1449
# Processing 181 to 201 out of 1449
# Processing 201 to 221 out of 1449
# Processing 221 to 241 out of 1449
# Processing 241 to 261 out of 1449
# Processing 261 to 281 out of 1449
# Processing 281 to 301 out of 1449
# Processing 301 to 321 out of 1449
# Processing 321 to 341 out of 1449
# Processing 341 to 361 out of 1449
# Processing 361 to 381 out of 1449
# Processing 381 to 401 out of 1449
# Processing 401 to 421 out of 1449
# Processing 421 to 441 out of 1449
# Processing 441 to 461 out of 1449
# Processing 461 to 481 out of 1449
# Processing 481 to 501 out of 1449
# Processing 501 to 521 out of 1449
# Processing 521 to 541 out of 1449
# Processing 541 to 561 out of 1449
# Processing 561 to 581 out of 1449
# Processing 581 to 601 out of 1449
# Processing 601 to 621 out of 1449
# Processing 621 to 641 out of 1449
# Processing 641 to 661 out of 1449
# Processing 661 to 681 out of 1449
# Processing 681 to 701 out of 1449
# Processing 701 to 721 out of 1449
# Processing 721 to 741 out of 1449
# Processing 741 to 761 out of 1449
# Processing 761 to 781 out of 1449
# Processing 781 to 801 out of 1449
# Processing 801 to 821 out of 1449
# Processing 821 to 841 out of 1449
# Processing 841 to 861 out of 1449
# Processing 861 to 881 out of 1449
# Processing 881 to 901 out of 1449
# Processing 901 to 921 out of 1449
# Processing 921 to 941 out of 1449
# Processing 941 to 961 out of 1449
# Processing 961 to 981 out of 1449
# Processing 981 to 1001 out of 1449
# Processing 1001 to 1021 out of 1449
# Processing 1021 to 1041 out of 1449
# Processing 1041 to 1061 out of 1449
# Processing 1061 to 1081 out of 1449
# Processing 1081 to 1101 out of 1449
# Processing 1101 to 1121 out of 1449
# Processing 1121 to 1141 out of 1449
# Processing 1141 to 1161 out of 1449
# Processing 1161 to 1181 out of 1449
# Processing 1181 to 1201 out of 1449
# Processing 1201 to 1221 out of 1449
# Processing 1221 to 1241 out of 1449
# Processing 1241 to 1261 out of 1449
# Processing 1261 to 1281 out of 1449
# Processing 1281 to 1301 out of 1449
# Processing 1301 to 1321 out of 1449
# Processing 1321 to 1341 out of 1449
# Processing 1341 to 1361 out of 1449
# Processing 1361 to 1381 out of 1449
# Processing 1381 to 1401 out of 1449
# Processing 1401 to 1421 out of 1449
# Processing 1421 to 1441 out of 1449
# Processing 1441 to 1449 out of 1449
#
# ✅ L3 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 - 20 out of 1449
# Processing 21 - 40 out of 1449
# Processing 41 - 60 out of 1449
# Processing 61 - 80 out of 1449
# Processing 81 - 100 out of 1449
# Processing 101 - 120 out of 1449
# Processing 121 - 140 out of 1449
# Processing 141 - 160 out of 1449
# Processing 161 - 180 out of 1449
# Processing 181 - 200 out of 1449
# Processing 201 - 220 out of 1449
# Processing 221 - 240 out of 1449
# Processing 241 - 260 out of 1449
# Processing 261 - 280 out of 1449
# Processing 281 - 300 out of 1449
# Processing 301 - 320 out of 1449
# Processing 321 - 340 out of 1449
# Processing 341 - 360 out of 1449
# Processing 361 - 380 out of 1449
# Processing 381 - 400 out of 1449
# Processing 401 - 420 out of 1449
# Processing 421 - 440 out of 1449
# Processing 441 - 460 out of 1449
# Processing 461 - 480 out of 1449
# Processing 481 - 500 out of 1449
# Processing 501 - 520 out of 1449
# Processing 521 - 540 out of 1449
# Processing 541 - 560 out of 1449
# Processing 561 - 580 out of 1449
# Processing 581 - 600 out of 1449
# Processing 601 - 620 out of 1449
# Processing 621 - 640 out of 1449
# Processing 641 - 660 out of 1449
# Processing 661 - 680 out of 1449
# Processing 681 - 700 out of 1449
# Processing 701 - 720 out of 1449
# Processing 721 - 740 out of 1449
# Processing 741 - 760 out of 1449
# Processing 761 - 780 out of 1449
# Processing 781 - 800 out of 1449
# Processing 801 - 820 out of 1449
# Processing 821 - 840 out of 1449
# Processing 841 - 860 out of 1449
# Processing 861 - 880 out of 1449
# Processing 881 - 900 out of 1449
# Processing 901 - 920 out of 1449
# Processing 921 - 940 out of 1449
# Processing 941 - 960 out of 1449
# Processing 961 - 980 out of 1449
# Processing 981 - 1000 out of 1449
# Processing 1001 - 1020 out of 1449
# Processing 1021 - 1040 out of 1449
# Processing 1041 - 1060 out of 1449
# Processing 1061 - 1080 out of 1449
# Processing 1081 - 1100 out of 1449
# Processing 1101 - 1120 out of 1449
# Processing 1121 - 1140 out of 1449
# Processing 1141 - 1160 out of 1449
# Processing 1161 - 1180 out of 1449
# Processing 1181 - 1200 out of 1449
# Processing 1201 - 1220 out of 1449
# Processing 1221 - 1240 out of 1449
# Processing 1241 - 1260 out of 1449
# Processing 1261 - 1280 out of 1449
# Processing 1281 - 1300 out of 1449
# Processing 1301 - 1320 out of 1449
# Processing 1321 - 1340 out of 1449
# Processing 1341 - 1360 out of 1449
# Processing 1361 - 1380 out of 1449
# Processing 1381 - 1400 out of 1449
# Processing 1401 - 1420 out of 1449
# Processing 1421 - 1440 out of 1449
#
# ✅ L1 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 - 50 out of 64
# Processing 1 - 49 out of 64
# Processing 51 - 99 out of 64
#
# ✅ L2 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 to 21 out of 64
# Processing 21 to 41 out of 64
# Processing 41 to 61 out of 64
# Processing 61 to 64 out of 64
#
# ✅ L3 執行成功。標準輸出：
# What is the prefix of your exhibition?Processing 1 - 20 out of 65
# Processing 21 - 40 out of 65
# Processing 41 - 60 out of 65

# %%
prefix='foodexpopro'


df = pd.read_json('/Users/rowena/Other Projects/external_data_study/Result/Exhibition Organizers/HKTDC//'+prefix+'/hktdc_'+prefix+'_L1.json', orient='records', lines=True)

df.to_csv('/Users/rowena/Other Projects/external_data_study/Result/Exhibition Organizers/HKTDC/'+prefix+'/hktdc_'+prefix+'_L1.csv',index=False)

# %%
int(1449/20)
# Out:
# 72
