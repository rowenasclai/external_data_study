# %%
import pandas as pd

# %%
df = pd.read_json('/Users/rowena/Other Projects/external_data_study/PY/Event Organizer/messe_frankfurt_control.json', lines=True,encoding='utf-8')

# %%
df.to_csv('/Users/rowena/Other Projects/external_data_study/Result/Exhibition Organizers/Messe_Frankfurt/messe_frankfurt_control.csv')
