# %%
import pandas as pd
import json

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

# %%
df = pd.read_json('/Users/rowena/asia_fruit_logistica.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df = pd.read_json('/Users/rowena/asia_fruit_logistica.json', lines=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/json/_json.py:804, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     802     return json_reader
#     803 else:
# --> 804     return json_reader.read()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/json/_json.py:1012, in JsonReader.read(self)
#    1010         data = ensure_str(self.data)
#    1011         data_lines = data.split("\n")
# -> 1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
#    1014     obj = self._get_object_parser(self.data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/json/_json.py:1040, in JsonReader._get_object_parser(self, json)
#    1038 obj = None
#    1039 if typ == "frame":
# -> 1040     obj = FrameParser(json, **kwargs).parse()
#    1042 if typ == "series" or obj is None:
#    1043     if not isinstance(dtype, bool):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/json/_json.py:1173, in Parser.parse(self)
#    1172 def parse(self):
# -> 1173     self._parse()
#    1175     if self.obj is None:
#    1176         return None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/json/_json.py:1366, in FrameParser._parse(self)
#    1362 orient = self.orient
#    1364 if orient == "columns":
#    1365     self.obj = DataFrame(
# -> 1366         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1367     )
#    1368 elif orient == "split":
#    1369     decoded = {
#    1370         str(k): v
#    1371         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1372     }
#
# ValueError: Expected object or value

# %%
with open('/Users/rowena/asia_fruit_logistica.json', 'r') as file:
    data = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[27], line 2
#       1 with open('/Users/rowena/asia_fruit_logistica.json', 'r') as file:
# ----> 2     data = json.load(file)
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 9 column 3 (char 1284)

# %%
data
# Out:
# [{'exhibitor': '2BFresh MicrogreensIsraelExporter, Grower/Producerhttp://www.2bfresh.com',
#   'industry': '',
#   'email': 'mailto:avner@taprojects.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S08',
#   'description': '2BFRESH is a leading producer of premium microgreens and baby vegetables, while also supplying fresh herbs and edible flowers to customers worldwide. Since 2012, the company has pioneered the concept of ready-to-use cut microgreens, offering a fresher, healthier, and more convenient solution that reduces labor, preparation time, and food waste. With growing farms in Israel, Switzerland, and Portugal, and a strong presence in the Hong Kong market for many years, 2BFRESH delivers consistent quality and year-round supply. Our microgreens provide a vibrant visual appeal and exceptional nutritional value, making them the perfect ingredient for garnishing dishes, enriching salads and sandwiches, and boosting smoothies with fresh flavor and natural goodness.',
#   'description_tc': '2BFRESH 是優質微型蔬菜（Microgreens）及嫩菜（Baby Vegetables）的專業生產商，同時供應新鮮香草及食用花卉，服務全球市場。自 2012 年起，公司率先推出即開即用的切割微型蔬菜，為餐飲業及零售市場提供更新鮮、更健康、更方便的選擇，同時有效節省備料時間、降低人力成本及減少食物浪費。\n\n2BFRESH 在以色列、瑞士及葡萄牙設有種植農場，並多年深耕香港市場，提供穩定可靠的全年供應。我們的微型蔬菜色彩鮮艷、外觀精緻，富含營養，是點綴菜式、提升沙律及三文治風味，以及為果昔（Smoothies）增添天然營養與新鮮口感的理想食材。'},
#  {'exhibitor': '3 Brothers Agri Export Private Limited3 BROTHERS AGRI EXPORT PRIVATE LIMITEDIndiaManufacturerhttp://3brothersagri.com/',
#   'industry': '3 BROTHERS AGRI EXPORT PRIVATE LIMITED',
#   'email': 'mailto:info@skagriexports.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C55',
#   'description': 'We are among the largest Potato Flakes Manufacturer, the first for the Norther India.'},
#  {'exhibitor': 'A.P. Moller – Maersk马士基ChinaTransport handlinghttp://www.maersk.com',
#   'industry': '马士基',
#   'email': 'mailto:baylie.zhang@maersk.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5G01',
#   'description': "A.P. Moller - Maersk(Maersk) is an integrated logistics company working to connect and simplify customers' supply chain. As a global leader in logistics services, the company has 100,0000+ customers, operates in almost 130 countries and employs 100,0000+people. Maersk is committed to reaching net-zero emissions by 2040 across the entire supply chain with new technologies, new vessels and green energy solutions. \n\nMaersk works to provide customers with a simple end-to-end offering of products and services, seamless customer engagement and a superior end-to-end delivery network, taking the complexity out of global supply chains.",
#   'description_tc': '作为一家综合性集装箱物流公司，A.P.穆勒 – 马士基致力于连接和简化我们客户的供应链。作为物流服务领域的全球领导者，公司拥有100,0000多家客户，业务遍及130多个国家，拥有100,000名员工。A.P.穆勒 – 马士基致力于通过新技术、新船舶和绿色能源解决方案，到2040年实现全供应链的净零排放。'},
#  {'exhibitor': 'Aartsen Asia LimitedHong Kong, ChinaWholesale/Distributor, Importerhttp://www.aartsen.com/en',
#   'industry': '',
#   'email': 'mailto:marketing@aartsen.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C42',
#   'description': 'When it comes to fresh, Aartsen goes beyond the extra mile. We offer everything in the world of fruit and vegetables. Literally. Every day, we make sure that our range of fresh fruit and vegetables from around the world finds its way to our customers. We call this NONSTOPFRESH. This makes Aartsen the one and only true international gateway for fruit and vegetables. Aartsen will do anything to deliver fruit and vegetables fresher then fresh to one of our Benelux destinations or to Hong Kong. 24 hours a day, 7 days a week we aim for the very best quality and service. Here too we go further than everyone else. Partners based in all corners of the world make this possible. They grow the finest fruit and vegetables for us. And we ensure that their business continue to grow.'},
#  {'exhibitor': 'Abdel Wahab Sons Co.EgyptExporterhttp://www.Abdelwahab-sons.com',
#   'industry': '',
#   'email': 'mailto:abdelwahab.fruit@yahoo.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W30',
#   'description': 'One of the biggest exporters of fresh citrus in Egypt and we have a global scan machine that helps us to provide our clients with the best quality.\n\nQuality Certificates:\n( ISO 9001 - Global G.A.P - BRC - IFS - HACCP ) Abd El Wahab sons packing house is one of the largest packing houses in Egypt with a production capacity of up to 200 tons daily.'},
#  {'exhibitor': 'AbrafrutasBrazilExporter, Grower/Producer, Association/Institutionhttp://www.frutasdobrasil.org',
#   'industry': '',
#   'email': 'mailto:abrafrutas@abrafrutas.org',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J41',
#   'description': 'The Brazilian Association of Fruit Growers and Exporters was founded in 2014 and it is in charge of promoting Brazilian fresh fruits and derivatives abroad.\nThe main export products are: fresh melons, fresh mangoes, fresh limes, table grapes, avocados, aguacates, apples, guavas, fresh papayas, acai pulp and many other tropical fruits, pulps and juices.\nThe association has 98 active members which 72 are exporters. The non exporter members are strategic partners from the fruit supply chain, including packaging materials, farming inputs, technology and logistic companies. Together, they represent around 80% of the total fruit volume currently exported from Brasil. All the exporters are certified by international companies such as Global GAP, GRASP, Smeta, and others.',
#   'description_tc': '巴西水果種植者和出口商協會成立於2014年，負責在海外推廣巴西新鮮水果及其衍生性商品。\n主要出口產品有：新鮮甜瓜、新鮮芒果、新鮮酸橙、食用葡萄、酪梨和酪梨、蘋果、番石榴、新鮮木瓜、巴西莓果肉和許多其他熱帶水果、果肉和果汁。\n該協會有 88 名活躍會員，其中 68 名是出口商。其餘成員則是水果供應鏈的策略夥伴，包括包裝材料、農業投入、技術和物流公司。它們合計約佔巴西水果出口總量的 80%。'},
#  {'exhibitor': 'Ace Star International Trading Co., Ltd.ThailandExporter, Wholesale/Distributor, Retailerhttp://www.acestarinter.com',
#   'industry': '',
#   'email': 'mailto:admin@acestarinter.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S47',
#   'description': 'Ace Star International is a global supplier of Thai food from fresh to processed ones. Our products vary from fresh local fruits, canned food, and dried fruits.\nWith our own farm in Chanthaburi, we have a competitive edge in abundant resources in the heart of ASEAN Economic Community (AEC).\n\nMore importantly, we guarantee that all of our products are well certified and complied to standard and regulation in each country.\nTherefore, our customer can rest assured that your business is in good hands that provide excellent care from the beginning till the end of each shipment.'},
#  {'exhibitor': 'Acefresh Produce Co., Ltd.熹鲜农产品有限公司ChinaExporter, Wholesale/Distributor, Grower/Producerhttp://acefresh.net',
#   'industry': '熹鲜农产品有限公司',
#   'email': 'mailto:info@acefresh.net',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5T02P',
#   'description': 'Acefresh Fruit has over 10 years of experience in the storage,packaging, and export of fresh fruits. We have also established stable and cooperative relationships with enterprises across various fruit export processing bases. Our main products include apples, oranges, mandarins,pears, and more.\nAfter more than a decade of development, Acefresh has built a young, energetic team with high morale and drive, dedicated to fulfilling every purchase request from our customers. We deeply value long-term partnerships and are committed to providing only the highest quality and safest products. Moreover, we strive to deliver exceptional customer service, always standing ready to address any questions you may have about our products. Our sole goal is to exceed your expectations!'},
#  {'exhibitor': 'Advance Food LimitedAdvance Food LimitedHong Kong, ChinaWholesale/Distributor, Retailer, Importerhttps://advancefoodhk.boutir.com/',
#   'industry': 'Advance Food Limited',
#   'email': 'mailto:gloriali@advancefoodhk.com',
#   'hall': 'Hall',
#   'booth': 'BoothNo',
#   'description': 'Advance Food Limited specializes in food wholesale and supply chain integration, providing reliable fruit and food supplies to retailers, convenience stores, and the catering industry.\n\n• Fruit Wholesale Expertise: Offers a wide range of fresh fruits with guaranteed quality and stable supply.\n• Supply Chain Integration: Collaborates with logistics and cold-chain service providers to ensure efficient cross-border distribution.\n• Cross-Border Expansion: Actively expanding into the Greater Bay Area and Southeast Asian markets, building international partnerships.',
#   'description_tc': '進陞食專注於食品批發與供應鏈整合，為零售商、便利店及餐飲業提供穩定的果蔬及食品供應。\n果蔬批發能力：提供多元化新鮮果蔬，確保品質與供應穩定。\n供應鏈整合：與物流公司及冷鏈服務商合作，確保跨境配送效率。\n跨境拓展：積極開拓大灣區及東南亞市場，建立國際合作網絡。'},
#  {'exhibitor': 'Aegean Fresh Fruits and Vegetables Exporters’ AssociationTurkeyAssociation/Institutionhttps://www.eib.org.tr/',
#   'industry': '',
#   'email': 'mailto:tarim3@eib.org.tr',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S27',
#   'description': 'Aegean Fresh Fruits and Vegetables Exporter’s Association was founded in 1966 for the purpose of uniting the exportes of fresh fruits and vegetables located in the Aegean Region under a single roof. Basic goals of the association are to improve the reputation of the sectorand to carry out activities toward increasing exportation. With its more than 800 active members and exportation of over 1,3 billion dollars to 200 countries annually, Aegean Fresh Fruits and Vegetables Exporter’s Association aims to be your permanent adress for tastiness and freshness.'},
#  {'exhibitor': '2BFresh MicrogreensIsraelExporter, Grower/Producerhttp://www.2bfresh.com',
#   'industry': '',
#   'email': 'mailto:avner@taprojects.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S08',
#   'description': '2BFRESH is a leading producer of premium microgreens and baby vegetables, while also supplying fresh herbs and edible flowers to customers worldwide. Since 2012, the company has pioneered the concept of ready-to-use cut microgreens, offering a fresher, healthier, and more convenient solution that reduces labor, preparation time, and food waste. With growing farms in Israel, Switzerland, and Portugal, and a strong presence in the Hong Kong market for many years, 2BFRESH delivers consistent quality and year-round supply. Our microgreens provide a vibrant visual appeal and exceptional nutritional value, making them the perfect ingredient for garnishing dishes, enriching salads and sandwiches, and boosting smoothies with fresh flavor and natural goodness.',
#   'description_tc': '2BFRESH 是優質微型蔬菜（Microgreens）及嫩菜（Baby Vegetables）的專業生產商，同時供應新鮮香草及食用花卉，服務全球市場。自 2012 年起，公司率先推出即開即用的切割微型蔬菜，為餐飲業及零售市場提供更新鮮、更健康、更方便的選擇，同時有效節省備料時間、降低人力成本及減少食物浪費。\n\n2BFRESH 在以色列、瑞士及葡萄牙設有種植農場，並多年深耕香港市場，提供穩定可靠的全年供應。我們的微型蔬菜色彩鮮艷、外觀精緻，富含營養，是點綴菜式、提升沙律及三文治風味，以及為果昔（Smoothies）增添天然營養與新鮮口感的理想食材。'},
#  {'exhibitor': '3 Brothers Agri Export Private Limited3 BROTHERS AGRI EXPORT PRIVATE LIMITEDIndiaManufacturerhttp://3brothersagri.com/',
#   'industry': '3 BROTHERS AGRI EXPORT PRIVATE LIMITED',
#   'email': 'mailto:info@skagriexports.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C55',
#   'description': 'We are among the largest Potato Flakes Manufacturer, the first for the Norther India.'},
#  {'exhibitor': 'A.P. Moller – Maersk马士基ChinaTransport handlinghttp://www.maersk.com',
#   'industry': '马士基',
#   'email': 'mailto:baylie.zhang@maersk.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5G01',
#   'description': "A.P. Moller - Maersk(Maersk) is an integrated logistics company working to connect and simplify customers' supply chain. As a global leader in logistics services, the company has 100,0000+ customers, operates in almost 130 countries and employs 100,0000+people. Maersk is committed to reaching net-zero emissions by 2040 across the entire supply chain with new technologies, new vessels and green energy solutions. \n\nMaersk works to provide customers with a simple end-to-end offering of products and services, seamless customer engagement and a superior end-to-end delivery network, taking the complexity out of global supply chains.",
#   'description_tc': '作为一家综合性集装箱物流公司，A.P.穆勒 – 马士基致力于连接和简化我们客户的供应链。作为物流服务领域的全球领导者，公司拥有100,0000多家客户，业务遍及130多个国家，拥有100,000名员工。A.P.穆勒 – 马士基致力于通过新技术、新船舶和绿色能源解决方案，到2040年实现全供应链的净零排放。'},
#  {'exhibitor': 'Aartsen Asia LimitedHong Kong, ChinaWholesale/Distributor, Importerhttp://www.aartsen.com/en',
#   'industry': '',
#   'email': 'mailto:marketing@aartsen.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C42',
#   'description': 'When it comes to fresh, Aartsen goes beyond the extra mile. We offer everything in the world of fruit and vegetables. Literally. Every day, we make sure that our range of fresh fruit and vegetables from around the world finds its way to our customers. We call this NONSTOPFRESH. This makes Aartsen the one and only true international gateway for fruit and vegetables. Aartsen will do anything to deliver fruit and vegetables fresher then fresh to one of our Benelux destinations or to Hong Kong. 24 hours a day, 7 days a week we aim for the very best quality and service. Here too we go further than everyone else. Partners based in all corners of the world make this possible. They grow the finest fruit and vegetables for us. And we ensure that their business continue to grow.'},
#  {'exhibitor': 'Abdel Wahab Sons Co.EgyptExporterhttp://www.Abdelwahab-sons.com',
#   'industry': '',
#   'email': 'mailto:abdelwahab.fruit@yahoo.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W30',
#   'description': 'One of the biggest exporters of fresh citrus in Egypt and we have a global scan machine that helps us to provide our clients with the best quality.\n\nQuality Certificates:\n( ISO 9001 - Global G.A.P - BRC - IFS - HACCP ) Abd El Wahab sons packing house is one of the largest packing houses in Egypt with a production capacity of up to 200 tons daily.'},
#  {'exhibitor': 'AbrafrutasBrazilExporter, Grower/Producer, Association/Institutionhttp://www.frutasdobrasil.org',
#   'industry': '',
#   'email': 'mailto:abrafrutas@abrafrutas.org',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J41',
#   'description': 'The Brazilian Association of Fruit Growers and Exporters was founded in 2014 and it is in charge of promoting Brazilian fresh fruits and derivatives abroad.\nThe main export products are: fresh melons, fresh mangoes, fresh limes, table grapes, avocados, aguacates, apples, guavas, fresh papayas, acai pulp and many other tropical fruits, pulps and juices.\nThe association has 98 active members which 72 are exporters. The non exporter members are strategic partners from the fruit supply chain, including packaging materials, farming inputs, technology and logistic companies. Together, they represent around 80% of the total fruit volume currently exported from Brasil. All the exporters are certified by international companies such as Global GAP, GRASP, Smeta, and others.',
#   'description_tc': '巴西水果種植者和出口商協會成立於2014年，負責在海外推廣巴西新鮮水果及其衍生性商品。\n主要出口產品有：新鮮甜瓜、新鮮芒果、新鮮酸橙、食用葡萄、酪梨和酪梨、蘋果、番石榴、新鮮木瓜、巴西莓果肉和許多其他熱帶水果、果肉和果汁。\n該協會有 88 名活躍會員，其中 68 名是出口商。其餘成員則是水果供應鏈的策略夥伴，包括包裝材料、農業投入、技術和物流公司。它們合計約佔巴西水果出口總量的 80%。'},
#  {'exhibitor': 'Ace Star International Trading Co., Ltd.ThailandExporter, Wholesale/Distributor, Retailerhttp://www.acestarinter.com',
#   'industry': '',
#   'email': 'mailto:admin@acestarinter.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S47',
#   'description': 'Ace Star International is a global supplier of Thai food from fresh to processed ones. Our products vary from fresh local fruits, canned food, and dried fruits.\nWith our own farm in Chanthaburi, we have a competitive edge in abundant resources in the heart of ASEAN Economic Community (AEC).\n\nMore importantly, we guarantee that all of our products are well certified and complied to standard and regulation in each country.\nTherefore, our customer can rest assured that your business is in good hands that provide excellent care from the beginning till the end of each shipment.'},
#  {'exhibitor': 'Acefresh Produce Co., Ltd.熹鲜农产品有限公司ChinaExporter, Wholesale/Distributor, Grower/Producerhttp://acefresh.net',
#   'industry': '熹鲜农产品有限公司',
#   'email': 'mailto:info@acefresh.net',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5T02P',
#   'description': 'Acefresh Fruit has over 10 years of experience in the storage,packaging, and export of fresh fruits. We have also established stable and cooperative relationships with enterprises across various fruit export processing bases. Our main products include apples, oranges, mandarins,pears, and more.\nAfter more than a decade of development, Acefresh has built a young, energetic team with high morale and drive, dedicated to fulfilling every purchase request from our customers. We deeply value long-term partnerships and are committed to providing only the highest quality and safest products. Moreover, we strive to deliver exceptional customer service, always standing ready to address any questions you may have about our products. Our sole goal is to exceed your expectations!'},
#  {'exhibitor': 'Advance Food LimitedAdvance Food LimitedHong Kong, ChinaWholesale/Distributor, Retailer, Importerhttps://advancefoodhk.boutir.com/',
#   'industry': 'Advance Food Limited',
#   'email': 'mailto:gloriali@advancefoodhk.com',
#   'hall': 'Hall',
#   'booth': 'BoothNo',
#   'description': 'Advance Food Limited specializes in food wholesale and supply chain integration, providing reliable fruit and food supplies to retailers, convenience stores, and the catering industry.\n\n• Fruit Wholesale Expertise: Offers a wide range of fresh fruits with guaranteed quality and stable supply.\n• Supply Chain Integration: Collaborates with logistics and cold-chain service providers to ensure efficient cross-border distribution.\n• Cross-Border Expansion: Actively expanding into the Greater Bay Area and Southeast Asian markets, building international partnerships.',
#   'description_tc': '進陞食專注於食品批發與供應鏈整合，為零售商、便利店及餐飲業提供穩定的果蔬及食品供應。\n果蔬批發能力：提供多元化新鮮果蔬，確保品質與供應穩定。\n供應鏈整合：與物流公司及冷鏈服務商合作，確保跨境配送效率。\n跨境拓展：積極開拓大灣區及東南亞市場，建立國際合作網絡。'},
#  {'exhibitor': 'Aegean Fresh Fruits and Vegetables Exporters’ AssociationTurkeyAssociation/Institutionhttps://www.eib.org.tr/',
#   'industry': '',
#   'email': 'mailto:tarim3@eib.org.tr',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S27',
#   'description': 'Aegean Fresh Fruits and Vegetables Exporter’s Association was founded in 1966 for the purpose of uniting the exportes of fresh fruits and vegetables located in the Aegean Region under a single roof. Basic goals of the association are to improve the reputation of the sectorand to carry out activities toward increasing exportation. With its more than 800 active members and exportation of over 1,3 billion dollars to 200 countries annually, Aegean Fresh Fruits and Vegetables Exporter’s Association aims to be your permanent adress for tastiness and freshness.'},
#  {'exhibitor': 'AeroboticsUnited StatesTechnical serviceshttp://www.aerobotics.com',
#   'industry': '',
#   'email': 'mailto:marketing@aerobotics.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3D37',
#   'description': "Aerobotics works with growers to transform everyday farming operations with technology that supports smarter business decisions and ensures a sustainable future. Using industry-leading computer vision for agriculture, they provide a rich array of precision farming insights for growers to better measure, manage and protect their yields. \n\nAerobotics' flagship product TrueFruit is the world's leading AI solution for fruit measurement and forecasting. Get your size, quality and color data by just taking pictures with your smartphone. \n\nVisit www.aerobotics.com to learn more about Aerobotics and request a demo to see their insights in action."},
#  {'exhibitor': 'Afrimex TradingTunisiaExporter, Grower/Producer, Manufacturerhttp://www.afrimex.net',
#   'industry': '',
#   'email': 'mailto:info@afrimex.net',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5Q53',
#   'description': 'AFRIMEX is a Tunisian active company specialized in processing, packing and \nexporting date’s fruit products. \nWith a great know-how in export, we are operating on many countries such as \nGermany (Market share 15%), Italy (Market share 15%), The Netherland, The \nUnited Kingdom, Russia, Denmark, Norway, Sweden, Austria, Slovakia, Poland, \nBosnia and HerzegoniaSwitzerland, France, Canada, Brazil, UAE, India, \nIndonesia and many other regions. \nOur plant facility (ECODATTES) meets the most stringent \nrequirements in terms of food standards. Equipped with all new processing \nmachines for sorting, treatment and packaging and a big capacity of cold rooms \nstorage for the preservation of the product’s quality. \nWith our products, we place a high status on price & quality.'},
#  {'exhibitor': 'Afrisun Orchards LimitedKenyaExporterhttp://www.afrisunorchards.com',
#   'industry': '',
#   'email': 'mailto:info@afrisunorchards.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3Z02',
#   'description': 'Afrisun Orchards Limited is a premier Kenyan agricultural enterprise specializing in the sustainable production and export of world-class avocados. Leveraging Kenya’s rich volcanic soils and optimal equatorial climate, we produce fruit celebrated for its rich flavor, creamy texture, and superior nutritional profile. We look forward to celebrate our avocado success\nOur Varieties\nHass Avocados\nFuerte Avocados\nUnwavering Quality & Ethics\nTrust and transparency drive our operations. Afrisun Orchards is fully compliant with the highest international benchmarks, supported by key certifications:\nGlobalG.A.P.\nGRASP\nSMETA\nOur Advantage\nYear-Round Supply\nStrategic Logistics\nTraceability & Sustainability\nPartner with Us\nVisit our booth to learn and discuss more.',
#   'description_tc': 'Afrisun Orchards Limited 是一家肯尼亚顶级农业企业，专注于可持续生产和出口世界级的牛油果。依托肯尼亚肥沃的火山土壤和理想的赤道气候，我们生产的水果以丰富的风味、细腻的口感和优越的营养价值而闻名。我们期待与大家一起庆祝我们的牛油果成果。\n\n我们的品种\nHass 牛油果\nFuerte 牛油果\n\n始终如一的品质与诚信\n信任和透明是我们运营的核心。Afrisun Orchards 完全符合最高的国际标准，并获得了以下重要认证：\nGlobalG.A.P.\nGRASP\nSMETA\n\n我们的优势\n全年供应\n战略物流\n可追溯性与可持续性\n\n与我们合作\n欢迎来我们的展位了解更多信息，并进行交流。'},
#  {'exhibitor': 'AGO Import Export Company LimitedVietnamExporter, Importer, Manufacturerhttps://agoexim.com',
#   'industry': '',
#   'email': 'mailto:andynguyen@agoexim.com',
#   'hall': 'Virtual Exhibitor',
#   'description': "AGO Import Export Co., Ltd. is a leading agricultural exporter in Binh Thuan, Vietnam, with over 10 years of experience. Operating 4 modern factories, partnering with 100+ facilities, and backed by 200+ skilled workers, we ensure stable, high-quality output. We specialize in exporting premium tropical fruits, including dragon fruit, seedless lemons, coconuts, and passion fruit.\n\nOur closed logistics system guarantees peak freshness and rapid global delivery. AGO’s mission is to deliver safe, sustainable Vietnamese agricultural products to the world, elevating our national identity on the global trade map while improving farmers' livelihoods. We are dedicated to building lasting, mutually beneficial international partnerships."},
#  {'exhibitor': 'Agricola Don RicardoAgricola Don RicardoPeruGrower/Producerhttps://donricardo.com/en/',
#   'industry': 'Agricola Don Ricardo',
#   'email': 'mailto:sales@adr.com.pe',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5D41',
#   'description': 'Grower of top quality grapes, blueberries and mandarins while making commitment to overall well-being of our employees.',
#   'description_tc': 'Grower of top quality grapes, blueberries and mandarins while making commitment to overall well-being of our employees.'},
#  {'exhibitor': 'Agricola Kamuk SACPeruExporter, Grower/Producerhttps://agricolakamuk.com/',
#   'industry': '',
#   'email': 'mailto:maryoriehuamancaja@kamukperu.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J22',
#   'description': 'Agrícola Kamuk is a Peruvian food exporting company, with a wide experience in handling fresh, dried and canned products. We manage 130 hectares of crops with different products and are processed in our packing house in the Arequipa region. We export our products to different countries in America, Europe and Asia.\nOur vision is to maintain close long-term relationships with all our customers, providing quality service from start to finish in all stages of our process.\nWe have international certifications such as BRC, Smeta, Haccp, GlobalGap among others.'},
#  {'exhibitor': 'Agriculture And Food Authority - Horticultural Crops DirectorateKenyaAssociation/Institutionhttp://www.afa.go.ke',
#   'industry': '',
#   'email': 'mailto:directorhcd@afa.go.ke',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3Z02',
#   'description': 'Horticultural Crops Directorate is one of the directorates under the Agriculture and Food Authority (AFA). It is responsible for regulating the production, processing, and marketing of horticultural crops with the aim of promoting their competitiveness both locally and internationally. HCD plays a critical role in promoting the growth and development of the horticultural industry in Kenya, which is a major contributor to the country’s economy.'},
#  {'exhibitor': 'Agrifoods Brasil Imp and Exp LtdaBrazilAgent, Exporter, Importerhttp://www.agrifoods.nl',
#   'industry': '',
#   'email': 'mailto:info@agrifoods.nl',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3B03',
#   'description': 'Agrifoods Exports Brazilian Fruits. Apples, Figs, Grapes, Avocados, Limes, Ginger, Mangoes, Kaki, Atemoia, Dekopon,'},
#  {'exhibitor': 'Agrisweets for InvestmentEgyptExporterhttp://www.agrisweets.com',
#   'industry': '',
#   'email': 'mailto:info@agrisweets.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W38',
#   'description': 'At Agrisweets, we are a family business company that have +1000 acre farms and exporters of fresh fruits. We are dedicated to provide the highest quality fresh fruits and vegetables to global markets. Our team of professionals has over 30 years of experience in the industry, ensuring that our products are of the highest standard. We are committed to providing safe and top-quality produce to all of our customers. \n\nAs a rapidly growing company, we specialize in producing and exporting a wide variety of fruits and vegetables including Oranges, Mandarins, Lemons, Grapefruit, Grapes, Sweet Potato, and Dates. We are able to meet the diverse needs of our customers, including supermarkets and retailers, by offering a full range of services, from production and sourcing to handling, packaging, sal'},
#  {'exhibitor': 'Agro Alex Group Co. For Agricultural Industrialization, Import and ExportEgyptExporter, Grower/Producer, Manufacturerhttp://www.agroalexgroup.com',
#   'industry': '',
#   'email': 'mailto:export@agroalexgroup.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3V47',
#   'description': 'AGRO ALEX GROUP CO is a leading group of companies in the agricultural and export sectors in Egypt, founded in 1950 specializing in the cultivation, packing and export of fresh fruits and vegetables; especially potatoes, oranges and onion to over 33 countries worldwide. AAG has a very strict quality management; our packing station is BRC certified and our farms are Global G.A.P and GRASP certified'},
#  {'exhibitor': '2BFresh MicrogreensIsraelExporter, Grower/Producerhttp://www.2bfresh.com',
#   'industry': '',
#   'email': 'mailto:avner@taprojects.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S08',
#   'description': '2BFRESH is a leading producer of premium microgreens and baby vegetables, while also supplying fresh herbs and edible flowers to customers worldwide. Since 2012, the company has pioneered the concept of ready-to-use cut microgreens, offering a fresher, healthier, and more convenient solution that reduces labor, preparation time, and food waste. With growing farms in Israel, Switzerland, and Portugal, and a strong presence in the Hong Kong market for many years, 2BFRESH delivers consistent quality and year-round supply. Our microgreens provide a vibrant visual appeal and exceptional nutritional value, making them the perfect ingredient for garnishing dishes, enriching salads and sandwiches, and boosting smoothies with fresh flavor and natural goodness.',
#   'description_tc': '2BFRESH 是優質微型蔬菜（Microgreens）及嫩菜（Baby Vegetables）的專業生產商，同時供應新鮮香草及食用花卉，服務全球市場。自 2012 年起，公司率先推出即開即用的切割微型蔬菜，為餐飲業及零售市場提供更新鮮、更健康、更方便的選擇，同時有效節省備料時間、降低人力成本及減少食物浪費。\n\n2BFRESH 在以色列、瑞士及葡萄牙設有種植農場，並多年深耕香港市場，提供穩定可靠的全年供應。我們的微型蔬菜色彩鮮艷、外觀精緻，富含營養，是點綴菜式、提升沙律及三文治風味，以及為果昔（Smoothies）增添天然營養與新鮮口感的理想食材。'},
#  {'exhibitor': '3 Brothers Agri Export Private Limited3 BROTHERS AGRI EXPORT PRIVATE LIMITEDIndiaManufacturerhttp://3brothersagri.com/',
#   'industry': '3 BROTHERS AGRI EXPORT PRIVATE LIMITED',
#   'email': 'mailto:info@skagriexports.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C55',
#   'description': 'We are among the largest Potato Flakes Manufacturer, the first for the Norther India.'},
#  {'exhibitor': 'A.P. Moller – Maersk马士基ChinaTransport handlinghttp://www.maersk.com',
#   'industry': '马士基',
#   'email': 'mailto:baylie.zhang@maersk.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5G01',
#   'description': "A.P. Moller - Maersk(Maersk) is an integrated logistics company working to connect and simplify customers' supply chain. As a global leader in logistics services, the company has 100,0000+ customers, operates in almost 130 countries and employs 100,0000+people. Maersk is committed to reaching net-zero emissions by 2040 across the entire supply chain with new technologies, new vessels and green energy solutions. \n\nMaersk works to provide customers with a simple end-to-end offering of products and services, seamless customer engagement and a superior end-to-end delivery network, taking the complexity out of global supply chains.",
#   'description_tc': '作为一家综合性集装箱物流公司，A.P.穆勒 – 马士基致力于连接和简化我们客户的供应链。作为物流服务领域的全球领导者，公司拥有100,0000多家客户，业务遍及130多个国家，拥有100,000名员工。A.P.穆勒 – 马士基致力于通过新技术、新船舶和绿色能源解决方案，到2040年实现全供应链的净零排放。'},
#  {'exhibitor': 'Aartsen Asia LimitedHong Kong, ChinaWholesale/Distributor, Importerhttp://www.aartsen.com/en',
#   'industry': '',
#   'email': 'mailto:marketing@aartsen.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5C42',
#   'description': 'When it comes to fresh, Aartsen goes beyond the extra mile. We offer everything in the world of fruit and vegetables. Literally. Every day, we make sure that our range of fresh fruit and vegetables from around the world finds its way to our customers. We call this NONSTOPFRESH. This makes Aartsen the one and only true international gateway for fruit and vegetables. Aartsen will do anything to deliver fruit and vegetables fresher then fresh to one of our Benelux destinations or to Hong Kong. 24 hours a day, 7 days a week we aim for the very best quality and service. Here too we go further than everyone else. Partners based in all corners of the world make this possible. They grow the finest fruit and vegetables for us. And we ensure that their business continue to grow.'},
#  {'exhibitor': 'Abdel Wahab Sons Co.EgyptExporterhttp://www.Abdelwahab-sons.com',
#   'industry': '',
#   'email': 'mailto:abdelwahab.fruit@yahoo.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W30',
#   'description': 'One of the biggest exporters of fresh citrus in Egypt and we have a global scan machine that helps us to provide our clients with the best quality.\n\nQuality Certificates:\n( ISO 9001 - Global G.A.P - BRC - IFS - HACCP ) Abd El Wahab sons packing house is one of the largest packing houses in Egypt with a production capacity of up to 200 tons daily.'},
#  {'exhibitor': 'AbrafrutasBrazilExporter, Grower/Producer, Association/Institutionhttp://www.frutasdobrasil.org',
#   'industry': '',
#   'email': 'mailto:abrafrutas@abrafrutas.org',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J41',
#   'description': 'The Brazilian Association of Fruit Growers and Exporters was founded in 2014 and it is in charge of promoting Brazilian fresh fruits and derivatives abroad.\nThe main export products are: fresh melons, fresh mangoes, fresh limes, table grapes, avocados, aguacates, apples, guavas, fresh papayas, acai pulp and many other tropical fruits, pulps and juices.\nThe association has 98 active members which 72 are exporters. The non exporter members are strategic partners from the fruit supply chain, including packaging materials, farming inputs, technology and logistic companies. Together, they represent around 80% of the total fruit volume currently exported from Brasil. All the exporters are certified by international companies such as Global GAP, GRASP, Smeta, and others.',
#   'description_tc': '巴西水果種植者和出口商協會成立於2014年，負責在海外推廣巴西新鮮水果及其衍生性商品。\n主要出口產品有：新鮮甜瓜、新鮮芒果、新鮮酸橙、食用葡萄、酪梨和酪梨、蘋果、番石榴、新鮮木瓜、巴西莓果肉和許多其他熱帶水果、果肉和果汁。\n該協會有 88 名活躍會員，其中 68 名是出口商。其餘成員則是水果供應鏈的策略夥伴，包括包裝材料、農業投入、技術和物流公司。它們合計約佔巴西水果出口總量的 80%。'},
#  {'exhibitor': 'Ace Star International Trading Co., Ltd.ThailandExporter, Wholesale/Distributor, Retailerhttp://www.acestarinter.com',
#   'industry': '',
#   'email': 'mailto:admin@acestarinter.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S47',
#   'description': 'Ace Star International is a global supplier of Thai food from fresh to processed ones. Our products vary from fresh local fruits, canned food, and dried fruits.\nWith our own farm in Chanthaburi, we have a competitive edge in abundant resources in the heart of ASEAN Economic Community (AEC).\n\nMore importantly, we guarantee that all of our products are well certified and complied to standard and regulation in each country.\nTherefore, our customer can rest assured that your business is in good hands that provide excellent care from the beginning till the end of each shipment.'},
#  {'exhibitor': 'Acefresh Produce Co., Ltd.熹鲜农产品有限公司ChinaExporter, Wholesale/Distributor, Grower/Producerhttp://acefresh.net',
#   'industry': '熹鲜农产品有限公司',
#   'email': 'mailto:info@acefresh.net',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5T02P',
#   'description': 'Acefresh Fruit has over 10 years of experience in the storage,packaging, and export of fresh fruits. We have also established stable and cooperative relationships with enterprises across various fruit export processing bases. Our main products include apples, oranges, mandarins,pears, and more.\nAfter more than a decade of development, Acefresh has built a young, energetic team with high morale and drive, dedicated to fulfilling every purchase request from our customers. We deeply value long-term partnerships and are committed to providing only the highest quality and safest products. Moreover, we strive to deliver exceptional customer service, always standing ready to address any questions you may have about our products. Our sole goal is to exceed your expectations!'},
#  {'exhibitor': 'Advance Food LimitedAdvance Food LimitedHong Kong, ChinaWholesale/Distributor, Retailer, Importerhttps://advancefoodhk.boutir.com/',
#   'industry': 'Advance Food Limited',
#   'email': 'mailto:gloriali@advancefoodhk.com',
#   'hall': 'Hall',
#   'booth': 'BoothNo',
#   'description': 'Advance Food Limited specializes in food wholesale and supply chain integration, providing reliable fruit and food supplies to retailers, convenience stores, and the catering industry.\n\n• Fruit Wholesale Expertise: Offers a wide range of fresh fruits with guaranteed quality and stable supply.\n• Supply Chain Integration: Collaborates with logistics and cold-chain service providers to ensure efficient cross-border distribution.\n• Cross-Border Expansion: Actively expanding into the Greater Bay Area and Southeast Asian markets, building international partnerships.',
#   'description_tc': '進陞食專注於食品批發與供應鏈整合，為零售商、便利店及餐飲業提供穩定的果蔬及食品供應。\n果蔬批發能力：提供多元化新鮮果蔬，確保品質與供應穩定。\n供應鏈整合：與物流公司及冷鏈服務商合作，確保跨境配送效率。\n跨境拓展：積極開拓大灣區及東南亞市場，建立國際合作網絡。'},
#  {'exhibitor': 'Aegean Fresh Fruits and Vegetables Exporters’ AssociationTurkeyAssociation/Institutionhttps://www.eib.org.tr/',
#   'industry': '',
#   'email': 'mailto:tarim3@eib.org.tr',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3S27',
#   'description': 'Aegean Fresh Fruits and Vegetables Exporter’s Association was founded in 1966 for the purpose of uniting the exportes of fresh fruits and vegetables located in the Aegean Region under a single roof. Basic goals of the association are to improve the reputation of the sectorand to carry out activities toward increasing exportation. With its more than 800 active members and exportation of over 1,3 billion dollars to 200 countries annually, Aegean Fresh Fruits and Vegetables Exporter’s Association aims to be your permanent adress for tastiness and freshness.'},
#  {'exhibitor': 'AeroboticsUnited StatesTechnical serviceshttp://www.aerobotics.com',
#   'industry': '',
#   'email': 'mailto:marketing@aerobotics.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3D37',
#   'description': "Aerobotics works with growers to transform everyday farming operations with technology that supports smarter business decisions and ensures a sustainable future. Using industry-leading computer vision for agriculture, they provide a rich array of precision farming insights for growers to better measure, manage and protect their yields. \n\nAerobotics' flagship product TrueFruit is the world's leading AI solution for fruit measurement and forecasting. Get your size, quality and color data by just taking pictures with your smartphone. \n\nVisit www.aerobotics.com to learn more about Aerobotics and request a demo to see their insights in action."},
#  {'exhibitor': 'Afrimex TradingTunisiaExporter, Grower/Producer, Manufacturerhttp://www.afrimex.net',
#   'industry': '',
#   'email': 'mailto:info@afrimex.net',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5Q53',
#   'description': 'AFRIMEX is a Tunisian active company specialized in processing, packing and \nexporting date’s fruit products. \nWith a great know-how in export, we are operating on many countries such as \nGermany (Market share 15%), Italy (Market share 15%), The Netherland, The \nUnited Kingdom, Russia, Denmark, Norway, Sweden, Austria, Slovakia, Poland, \nBosnia and HerzegoniaSwitzerland, France, Canada, Brazil, UAE, India, \nIndonesia and many other regions. \nOur plant facility (ECODATTES) meets the most stringent \nrequirements in terms of food standards. Equipped with all new processing \nmachines for sorting, treatment and packaging and a big capacity of cold rooms \nstorage for the preservation of the product’s quality. \nWith our products, we place a high status on price & quality.'},
#  {'exhibitor': 'Afrisun Orchards LimitedKenyaExporterhttp://www.afrisunorchards.com',
#   'industry': '',
#   'email': 'mailto:info@afrisunorchards.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3Z02',
#   'description': 'Afrisun Orchards Limited is a premier Kenyan agricultural enterprise specializing in the sustainable production and export of world-class avocados. Leveraging Kenya’s rich volcanic soils and optimal equatorial climate, we produce fruit celebrated for its rich flavor, creamy texture, and superior nutritional profile. We look forward to celebrate our avocado success\nOur Varieties\nHass Avocados\nFuerte Avocados\nUnwavering Quality & Ethics\nTrust and transparency drive our operations. Afrisun Orchards is fully compliant with the highest international benchmarks, supported by key certifications:\nGlobalG.A.P.\nGRASP\nSMETA\nOur Advantage\nYear-Round Supply\nStrategic Logistics\nTraceability & Sustainability\nPartner with Us\nVisit our booth to learn and discuss more.',
#   'description_tc': 'Afrisun Orchards Limited 是一家肯尼亚顶级农业企业，专注于可持续生产和出口世界级的牛油果。依托肯尼亚肥沃的火山土壤和理想的赤道气候，我们生产的水果以丰富的风味、细腻的口感和优越的营养价值而闻名。我们期待与大家一起庆祝我们的牛油果成果。\n\n我们的品种\nHass 牛油果\nFuerte 牛油果\n\n始终如一的品质与诚信\n信任和透明是我们运营的核心。Afrisun Orchards 完全符合最高的国际标准，并获得了以下重要认证：\nGlobalG.A.P.\nGRASP\nSMETA\n\n我们的优势\n全年供应\n战略物流\n可追溯性与可持续性\n\n与我们合作\n欢迎来我们的展位了解更多信息，并进行交流。'},
#  {'exhibitor': 'AGO Import Export Company LimitedVietnamExporter, Importer, Manufacturerhttps://agoexim.com',
#   'industry': '',
#   'email': 'mailto:andynguyen@agoexim.com',
#   'hall': 'Virtual Exhibitor',
#   'description': "AGO Import Export Co., Ltd. is a leading agricultural exporter in Binh Thuan, Vietnam, with over 10 years of experience. Operating 4 modern factories, partnering with 100+ facilities, and backed by 200+ skilled workers, we ensure stable, high-quality output. We specialize in exporting premium tropical fruits, including dragon fruit, seedless lemons, coconuts, and passion fruit.\n\nOur closed logistics system guarantees peak freshness and rapid global delivery. AGO’s mission is to deliver safe, sustainable Vietnamese agricultural products to the world, elevating our national identity on the global trade map while improving farmers' livelihoods. We are dedicated to building lasting, mutually beneficial international partnerships."},
#  {'exhibitor': 'Agricola Don RicardoAgricola Don RicardoPeruGrower/Producerhttps://donricardo.com/en/',
#   'industry': 'Agricola Don Ricardo',
#   'email': 'mailto:sales@adr.com.pe',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5D41',
#   'description': 'Grower of top quality grapes, blueberries and mandarins while making commitment to overall well-being of our employees.',
#   'description_tc': 'Grower of top quality grapes, blueberries and mandarins while making commitment to overall well-being of our employees.'},
#  {'exhibitor': 'Agricola Kamuk SACPeruExporter, Grower/Producerhttps://agricolakamuk.com/',
#   'industry': '',
#   'email': 'mailto:maryoriehuamancaja@kamukperu.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J22',
#   'description': 'Agrícola Kamuk is a Peruvian food exporting company, with a wide experience in handling fresh, dried and canned products. We manage 130 hectares of crops with different products and are processed in our packing house in the Arequipa region. We export our products to different countries in America, Europe and Asia.\nOur vision is to maintain close long-term relationships with all our customers, providing quality service from start to finish in all stages of our process.\nWe have international certifications such as BRC, Smeta, Haccp, GlobalGap among others.'},
#  {'exhibitor': 'Agriculture And Food Authority - Horticultural Crops DirectorateKenyaAssociation/Institutionhttp://www.afa.go.ke',
#   'industry': '',
#   'email': 'mailto:directorhcd@afa.go.ke',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3Z02',
#   'description': 'Horticultural Crops Directorate is one of the directorates under the Agriculture and Food Authority (AFA). It is responsible for regulating the production, processing, and marketing of horticultural crops with the aim of promoting their competitiveness both locally and internationally. HCD plays a critical role in promoting the growth and development of the horticultural industry in Kenya, which is a major contributor to the country’s economy.'},
#  {'exhibitor': 'Agrifoods Brasil Imp and Exp LtdaBrazilAgent, Exporter, Importerhttp://www.agrifoods.nl',
#   'industry': '',
#   'email': 'mailto:info@agrifoods.nl',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3B03',
#   'description': 'Agrifoods Exports Brazilian Fruits. Apples, Figs, Grapes, Avocados, Limes, Ginger, Mangoes, Kaki, Atemoia, Dekopon,'},
#  {'exhibitor': 'Agrisweets for InvestmentEgyptExporterhttp://www.agrisweets.com',
#   'industry': '',
#   'email': 'mailto:info@agrisweets.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W38',
#   'description': 'At Agrisweets, we are a family business company that have +1000 acre farms and exporters of fresh fruits. We are dedicated to provide the highest quality fresh fruits and vegetables to global markets. Our team of professionals has over 30 years of experience in the industry, ensuring that our products are of the highest standard. We are committed to providing safe and top-quality produce to all of our customers. \n\nAs a rapidly growing company, we specialize in producing and exporting a wide variety of fruits and vegetables including Oranges, Mandarins, Lemons, Grapefruit, Grapes, Sweet Potato, and Dates. We are able to meet the diverse needs of our customers, including supermarkets and retailers, by offering a full range of services, from production and sourcing to handling, packaging, sal'},
#  {'exhibitor': 'Agro Alex Group Co. For Agricultural Industrialization, Import and ExportEgyptExporter, Grower/Producer, Manufacturerhttp://www.agroalexgroup.com',
#   'industry': '',
#   'email': 'mailto:export@agroalexgroup.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3V47',
#   'description': 'AGRO ALEX GROUP CO is a leading group of companies in the agricultural and export sectors in Egypt, founded in 1950 specializing in the cultivation, packing and export of fresh fruits and vegetables; especially potatoes, oranges and onion to over 33 countries worldwide. AAG has a very strict quality management; our packing station is BRC certified and our farms are Global G.A.P and GRASP certified'},
#  {'exhibitor': 'Agrochain Vietnam Co.,Ltd.AGROCHAIN VIETNAM CO.,LTDVietnamAgent, Exporter, Wholesale/Distributor, Retailer, Importer, Manufacturer, Research organisation, Association/Institution, Offline Retailer, Online Retailer, Other Serviceshttps://agrochainvn.com/',
#   'industry': 'AGROCHAIN VIETNAM CO.,LTD',
#   'email': 'mailto:simon@agrochainvn.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3U27',
#   'description': 'Agrochain Vietnam is a fresh produce exporter and international sourcing hub specializing in premium Vietnamese fresh fruits including bananas, coconuts, dragon fruits, passion fruits, mangoes, longans, rambutans, guavas, jackfruits, watermelons, and other tropical fruits. \n\nSupported by a strong network of farms, cooperatives, and packing facilities, we provide reliable supply, strict quality control, and end-to-end export solutions. We are committed to delivering safe, traceable, and market-compliant products to importers, wholesalers, distributors, and retail chains worldwide.',
#   'description_tc': 'Agrochain Vietnam 是一家专业的新鲜农产品出口商及国际采购服务平台，专注于向全球市场供应优质越南新鲜水果，包括香蕉、椰子、火龙果、百香果、芒果、龙眼、红毛丹、番石榴、菠萝蜜、西瓜及其他热带水果。\n\n依托完善的种植基地、合作社及包装加工设施网络，我们能够提供稳定可靠的货源、严格的质量管理以及一站式出口解决方案。我们致力于为全球进口商、批发商、分销商及零售连锁企业提供安全、可追溯且符合国际市场标准的优质产品。'},
#  {'exhibitor': 'AGROFEM农业有限元法PeruExporter, Grower/Producerhttp://www.agrofem.pe',
#   'industry': '农业有限元法',
#   'email': 'mailto:nzurita@agrofem.pe',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J22',
#   'description': 'AGROFEM, the fresh produce division of ZR Corporation S.A.C., is a Peruvian exporter dedicated to supplying premium fruits and vegetables to international markets. We offer fresh blueberries, Hass avocados, and snow peas (Snow & Sugar varieties), produced under sustainable farming practices with complete traceability from field to destination. Through rigorous quality assurance, reliable supply programs, and customer-oriented service, we deliver consistent products that meet the highest international standards. Our mission is to build long-term partnerships based on trust, quality, and operational excellence.',
#   'description_tc': 'AGROFEM 是 ZR Corporation S.A.C. 旗下专注于新鲜农产品出口的事业部门，致力于向全球市场供应高品质秘鲁新鲜果蔬。我们的主要产品包括新鲜蓝莓、哈斯牛油果及荷兰豆（Snow 和 Sugar 品种），采用可持续种植方式，并实现从农场到目的地的全程可追溯管理。凭借严格的质量管理体系、稳定可靠的供应能力和以客户为中心的服务理念，我们持续提供符合国际高标准的优质产品。我们致力于与全球合作伙伴建立基于诚信、品质和卓越运营的长期合作关系。'},
#  {'exhibitor': 'AgroFresh埃雷菲农业咨询(上海)有限公司ChinaStorage, Technical services, Packaginghttp://www.agrofresh.com',
#   'industry': '埃雷菲农业咨询(上海)有限公司',
#   'email': 'https://www.facebook.com/Agrofreshworld',
#   'hall': 'Virtual Exhibitor',
#   'description': 'AgroFresh is a global leader in post-harvest solutions, delivering science-based solutions that help maintain the freshness, quality, and value of fresh produce from harvest to consumption. With global reach and deep local expertise, AgroFresh combines innovation with practical, on-the-ground support to serve customers worldwide. The company partners with growers, packers and shippers to reduce waste, extend shelf life, and advance sustainability across the fresh produce value chain.',
#   'description_tc': '埃雷菲是全球领先的采后保鲜解决方案提供商，致力于运用最新的科学技术，帮助保持生鲜农产品从采收至消费全程的新鲜度、品质与价值。凭借全球网络与深厚的本土化专业经验，埃雷菲将创新技术与切实可行的本地支持相结合，为世界各地客户提供服务。公司与种植户、包材商和出口商合作，共同减少浪费、延长货架期，并推动整个生鲜农产品价值链的可持续发展。'},
#  {'exhibitor': 'Agroland for Agricultural ManufacturingEgyptExporterhttp://www.agroland-egypt.com',
#   'industry': '',
#   'email': 'mailto:info@agroland-egypt.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3W37',
# ...
#  {'exhibitor': 'BGP International Pty LtdAustraliaExporter, Wholesale/Distributor, Importer, Marketing organisationhttps://www.bgp.com.au/',
#   'industry': '',
#   'email': 'mailto:info@bgp.com.au',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3F37',
#   'description': 'BGP International is your global provider of fresh produce. \n\nWe are experts in the export and marketing of fresh produce with a lifetime of experience. We source the best produce from packers in Australia, Egypt, South Africa, India, America, China, Pakistan and more.'},
#  {'exhibitor': 'BGY Fruits深圳百果园实业（集团）股份有限公司ChinaExporter, Retailer, Importerhttps://www.pagoda.com.cn',
#   'industry': '深圳百果园实业（集团）股份有限公司',
#   'email': 'mailto:zhongyx@pagoda.com.cn',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5R21',
#   'description': 'Specializing in the fruit industry for 24 years, BGY FRUITS offers nearly 1,000 varieties of fruits directly sourced from 26 countries.\nBGY, an industry pioneer, sets the precedent of the fruit chain model. With 95 million members bearing witness to its achievements, BGY\'s unwavering commitment to quality, BGY has secured its position as the top-selling fruit retailer for 10 consecutive years.\nWith the mission to "Allow Everyone to Enjoy Life With Delicious Fruit", BGY aspires to become the world\'s best fruit company and to spearhead the global fruit industry.',
#   'description_tc': '百果园，专研水果24年，精选全球品质水果，26国直采近千种好果。\n百果园引领行业革新，开创水果专营连锁模式先河，9500万会员见证了百果园的成就，对品质的执着造就了全国水果专门零售，连续10年销量第一。\n百果园制定“四度一味一安全”水果分级体系，打造53个独家品牌专属美味水果，引导行业升级。坚守“良知”和“信任”文化，在行业内率先推出“三无退货”售后服务，并于2025年将其升级为覆盖消费全流程的放心买·随心退”服务，全力提升每一位顾客的水果消费幸福感。\n品质，是百果园的承诺。百果园运用先进的BLOF种植技术，携手全球超800个精选基地，聚集300位专业采购人员，甄选全球高品质水果。创新冷链运输技术，更是将新鲜好果跨越千里送到顾客面前。\n百果园肩负的使命，是让天下人享受水果好生活，致力成为全球第一的果业公司，领航全球果业发展。'},
#  {'exhibitor': 'Binchuan Shengshi Xin Agricultural Technology Co., Ltd.宾川盛世鑫农业科技有限公司ChinaExporterhttps://www.qcc.com/firm/01f82ce90c4a731a1b61847e7e4d7d04.html',
#   'industry': '宾川盛世鑫农业科技有限公司',
#   'email': 'mailto:417529027@qq.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5B30',
#   'description': 'Binchuan Shengshixin Agricultural Technology Co., Ltd.Founded in 2021, Binchuan Shengshixin Agricultural Technology Co., Ltd. is located in Liujiawan Plateau Characteristic Food Processing Industrial Park, Jinniu Town, Binchuan County, Dali Bai Autonomous Prefecture, Yunnan Province. We specialize in the import and export trade of fruits, boasting extensive industry experience and an outstanding market reputation.Adhering to the tenet of "Quality Oriented, Reputation Supreme", we guarantee the freshness and premium quality of all fruits. We take safeguarding customers’ health and delivering customer satisfaction as our core responsibility, and strictly follow the standards of pollution-free green agriculture and ecological green production. Your satisfaction is the driving force behind',
#   'description_tc': '宾川盛世鑫农业科技有限公司成立于2021年，地址位于云南省大理白族自治州宾川县金牛镇柳家湾高原特色食品加工产业园，我们专注于水果进出口贸易，具有丰富经验和卓越口碑，我们将秉承质量为本、信誉至上的宗旨，保证水果的新鲜与品质，以顾客健康、顾客满意为已任，坚持无公害绿色农业、绿色生态的标准，你们的满意是我们持续向上的动力。'},
#  {'exhibitor': 'BioXTEND Inc.United StatesExporter, Technical services, Manufacturerhttp://www.BioXTEND.com',
#   'industry': '',
#   'email': 'mailto:info@bioxtendco.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J57',
#   'description': 'US Manufacturer and marketer of Ethylene Absorbers for fruit preservation in the global supply chain: ethylene filters for containers & trailers, ethylene absorber sachets for produce boxes, ethylene BXT Shields for pallets. digital and analog temperature recorders and data loggers for cold chain monitoring.'},
#  {'exhibitor': 'BiteRiot OperationsAustraliaExporter, Grower/Producerhttp://www.biteriot.com.au',
#   'industry': '',
#   'email': 'mailto:sales@biteriot.com.au',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3F16',
#   'description': "The BiteRiot! brand is the brainchild of the Hall family, who have been growing world-class fruit in Australia's central west NSW for almost 50 years. Along with their orchards, located on the foothills of Mount Canobolas, BiteRiot encompasses over 25 local growers of apples and cherries. BiteRiot Operations market some of Australia’s best apples and cherries, which can now be found in supermarkets all over the world."},
#  {'exhibitor': 'Blue ValleyBlue ValleyEgyptExporter, Importer, Packaginghttp://www.bluevalley-eg.com',
#   'industry': 'Blue Valley',
#   'email': 'mailto:sales@bluevalley-eg.com',
#   'hall': 'Virtual Exhibitor',
#   'description': 'lue Valley is an Egyptian company exports a variety of fresh fruits and vegetables from certified farms under strict food safety standards.\n\nBlue Valley, is committed to innovation and runs an integrated management system that shapes every step of its process — focused on quality standards, environmental care, social responsibility, health & safety, and ongoing product development.'},
#  {'exhibitor': 'Blue WhaleFranceExporter, Grower/Producerhttps://www.blue-whale.com/en/',
#   'industry': '',
#   'email': 'mailto:julien.baumann@blue-whale.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3U15',
#   'description': 'Blue Whale is a French fruit growers’ group with more than 50 years of experience. Present across four French production regions, the group markets five fruit categories (apples, pears, kiwis, plums, and grapes) supported by a broad varietal portfolio to meet the expectations of the most demanding markets.\n \nBlue Whale stands for fully traceable production, with a strong focus on taste and a commitment to increasingly sustainable agriculture. As the French leader in pome fruit exports, the group ships more than 1,000 containers worldwide every year.\n \nThe group is also actively engaged in ambitious R&D projects to develop fruits that are both appealing and sustainable for today and future generations. In 2025, Blue Whale achieved a turnover of €365 million.'},
#  {'exhibitor': 'Boix (Jiaxing) Packaging Equipments Co., Ltd.博盒世（嘉兴) 包装设备有限公司ChinaExporter, Manufacturer, Packaginghttp://www.boix.com',
#   'industry': '博盒世（嘉兴) 包装设备有限公司',
#   'email': 'mailto:johanawang@boix.cn',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3C25',
#   'description': 'W e l c o m e  t o  B o i x \nYour Box Forming Partner, that is who we are! \nWe are a leading designer and manufacturer of industrial machines for forming, erecting and gluing corrugated and solid cardboard boxes. \nThe company prides itself on providing its customers with a true sustainability advantage. \nWith already more than 50 years of experience, the Boix Group has become a regional and global market leader in the development and production of tray forming machines for sustainable packaging. \nThe company continues to be a family-owned business, which is now in the hands of the second generation and today employs around 350 people all over the world.',
#   'description_tc': '欢迎来到Boix\n我们是您的纸箱成型好伙伴！ \n做为包装行业设备领跑设计者和制造商，我们专注于设计和制造适合瓦楞纸箱和硬纸板箱的成型机设备。 \n让我们感到无比自豪的是我们能够为我们的客户提供真正的可持续发展优势。 \n从公司成立到现在我们已经积累了50多年的经验，Boix集团已经成长为一家开发和生产用于可持续包装的纸箱成型机的行业和全球市场领跑者。 \n公司继续延续着从创始人开始到现在的家族式企业经营模式，如今正由家族的第二代成员管理公司业务，目前在全球拥有大约350名员工。'},
#  {'exhibitor': 'Bostock New ZealandNew ZealandExporter, Grower/Producerhttp://www.bostock.nz',
#   'industry': '',
#   'email': 'mailto:enquiries@bostock.nz',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5R22',
#   'description': 'BOSTOCK New Zealand is 100% owned by John Bostock and is based in Hawke’s Bay, one of the cleanest and purest growing environments in the world. We are one of New Zealand’s leading produce growers, packers and exporters.  \n\nWe have been exporting premium produce for more than 30 years – including organic and conventional apples, squash, onions and grain.  Bostock New Zealand are the largest organic apple producer in both New Zealand and the Southern Hemisphere.  Each year; we export approximately 600,000 cartons of organic apples globally. \n\nBostock also proudly export conventional apples on behalf of ourselves and independent orchardists. We currently export around 1.5 million cartons of conventional NZ apples each year including our proprietary varieties Dazzle, Premier Star and Lumi.'},
#  {'exhibitor': 'Botou Dongfang Fruit Co., Ltd.泊头东方果品有限公司ChinaGrower/Producerhttp://www,btdfgp.com',
#   'industry': '泊头东方果品有限公司',
#   'email': 'mailto:df-fruit@btdfgp.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5K37G',
#   'description': 'Founded in 1997, Botou Dongfang Fruit Co., Ltd. is located in Botou City, Hebei Province, known as "China’s No.1 Hometown of Ya Pears". It is a national key leading enterprise in agricultural industrialization.\n\nThe company is a professional enterprise integrating fruit planting, vegetable cultivation, processing, storage, import and export sales. Its products are sold to more than 30 countries and regions including the United States, Canada, Australia, Israel and Brazil and so on.\n\nThe company has successively obtained HACCP food management system certification, Global GAP Good Agricultural Practices certification, BRC Global Standard for Food Safety certification and SMETA social responsibility audit certification.\nIt has hosted multiple landmark export launch ceremonies: the shipment c',
#   'description_tc': '泊头东方果品有限公司成立于一九九七年，位于被誉为“中国鸭梨第一乡”的河北省泊头市，是农业产业化“国家级重点龙头企业”。\n公司是一家集果品种植、蔬菜生产、加工、储藏、进出口销售于一体的专业公司。产品现已远销美国、加拿大、澳大利亚、以色列、巴西、等30多个国家和地区。\n公司先后取得haccp食品管理体系认证；global gap 全球良好农业操作规范体系认证；BRC国际食品安全认证；SMETA社会责任认证。公司成功举办了中国鲜梨1999年澳大利亚、2007年输美的发运仪式、2015年以色列、2020年巴西的首发仪式，2025年中国冬枣出口澳大利亚的首发仪式和2020年我司完成冬枣首发智利的签约仪式。\n东方果品持续助力科技兴农。与全球领先品种公司合作，引入中国市场富有潜力的优秀品种，授权在中国适宜产区规模化种植，推动中国品种知识产权保护。'},
#  {'exhibitor': 'Botou Longsheng Fruit Co., Ltd.泊头市龙胜果品有限公司ChinaGrower/Producerhttp://www.btdfgp.com',
#   'industry': '泊头市龙胜果品有限公司',
#   'email': 'mailto:dongfang@btdfgp.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5K37J',
#   'description': 'Botou Longsheng Fruit Co., Ltd. was founded in 2015. It is a modern professional enterprise integrating fruit and vegetable cultivation, intensive processing, cold chain warehousing and foreign trade export, and has been awarded the title of Key Leading Enterprise of Agricultural Industrialization in Hebei Province. Its products are sold to more than 40 countries and regions across North America, South America, Oceania, Europe and Southeast Asia.\n\nSince its inception, the company has adhered to the development philosophy of "empowerment by science and technology, development guided by the market", and kept upgrading towards industrialized, large-scale and standardized operation. It has developed the distinctive industrial operation model of "Company + Bases (Cooperatives) + Farmers". It co',
#   'description_tc': '泊头市龙胜果品有限公司成立于2015年，是一家集果品、蔬菜生产、加工、储藏、出口销售于一体的专业公司，是河北省农业产业化重点龙头企业。产品现已远销北美洲、南美洲、澳洲、欧洲及东南亚的40多个国家和地区。\n公司成立以来，即“以科技为依托，以市场为导向”，逐步向产业化、规模化、标准化方向发展完善，深化“公司+基地（合作社）+农户”的产业化经营模式，上联市场，对接协会、下联果农，组织果农实行“六统一”标准化管理和服务，即统一施肥浇水、统一人工授粉、统一疏花疏果、统一防治病虫、统一套袋、统一采摘贮存。公司与合作社、合作社与果农形成了“利益共享、利润返还、风险共担”的利益联结机制。基地建设即为公司提供了充足的高品质货源，真正实现了“订单农业”，公司发展，果农增收，为农业产业化发展、农业区域结构调整发挥了示范带动作用。\n公司面对国内外市场形势，我们深刻反思，认识到企业要在激烈的市场竞争中求生存、求发展，必须要有合格的产品质量，必须尽快改变片面追求产量的生产现状，按照生产标准和操作规程，严密组织实施标准化生产，全面提高果品质量和品质，公司与大专院校的专家教授合作，制定了科学的果树管理标准，通过“三化一延伸”的生产管理模式进行全面推广，通过实行“三化一延伸”的管理模式，带动合同果农5000余户，而且公司辐射带动当地及周边地区1万户果农进行标准化生产，企业从事农产品生产、加工、流通过程中，通过合同、合作和股份合作方式从果农或合作社采购的货物占销售量的90%以上。农户即为公司提供了充足的高品质货源，又增加了收入，2024年基地农户年增收2000元。我公司将发挥龙头带动作用，深化农业产业化经营，为国家经济快速发展，为社会主义新农村建设作出更大的贡献。'},
#  {'exhibitor': 'Botou Panglong Fruit Products Responsibility Co., Ltd.泊头市庞龙果品有限责任公司ChinaExporter, Grower/Producerhttp://www.glfruit.com',
#   'industry': '泊头市庞龙果品有限责任公司',
#   'email': 'mailto:sale_cathy@glfruit.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5T22P',
#   'description': 'BOTOU PANGLONG FRUIT PRODUCTS RESPONSIBILITY CO.,LTD was founded in 2003，our company has self-operation import and export right，set fruit vegetable planting，processing，refrigeration and sales export as an foreign trade enterprise.Awarded as “Class A Management Enterprise” by Shijiazhuang Customs of Hebei Province.Cool Pear brand awarded famous of Hebei Province.The annual export of fresh pear is 50.000 tons,and the fresh pear export volume ranks first in Hebei Province for seven consecutive years.\nPanglong Fruit Company covers an area of 30,000 square meters,building  area 15,000 square meters.As a large -scale processing company which registered by National Customs ,Synthesis processing capacity is 200ton per day,registered orchard area 10,055 Mu.',
#   'description_tc': '泊头市庞龙果品有限责任公司成立于2003年, 公司拥有独立的进出口权，集果品蔬菜种植、加工、储藏、销售出口为一体的外贸企业。 被河北省石家庄海关评定为“A类管理企业”。“廣龍”牌商标荣获河北省著名商标。年出口鲜梨5万吨左右，连续七年鲜梨出口量位居河北省首位。\n庞龙果品公司占地面积3万平方米，建筑面积1.5万平方米。有经国家海关部门注册登记的大型加工厂，综合日加工能力200吨,注册登记果园面积10055亩。'},
#  {'exhibitor': 'Botou Yafeng Fruit Co., Ltd.泊头亚丰果品有限公司ChinaExporter, Grower/Producer, Retailerhttp://www.yafengfruit.com',
#   'industry': '泊头亚丰果品有限公司',
#   'email': 'mailto:btyfgp@163.com',
#   'hall': 'Hall5',
#   'booth': 'BoothNo5P21B',
#   'description': 'Botou Yafeng Botou Yafeng Fruit Co., LTD.\nBotou Yafeng Fruit Co., Ltd. is a leading agricultural industrialization enterprise specializing in fruit planting and processing, storage, sales, import and export of goods, agricultural technology research and development, and consulting services.\nAt present, Yafeng has a comprehensive cold storage group, with a total storage capacity of more than 30,000 tons; Free orchard 2000 acres, 10,000 acres of cooperative orchard, 4290 acres of standardized base orchard and two fruit processing factory certified by the United States, Canada, Australia, New Zealand and other countries, customs registration.',
#   'description_tc': '泊头亚丰果品有限公司是一家以果品种植、加工、储藏、销售、货物进出口、农业技术研发、咨询服务为一体的农业产业化龙头企业。成立于1991年，总部位于被誉为“中国鸭梨之乡”的河北省泊头市廊泊路工业区。\n目前，亚丰公司拥有综合性冷库群，总储藏能力3万余吨；自有果园2000亩，合作果园10000亩，有经美国、加拿大、澳大利亚、新西兰等国家认证，海关部门注册登记的标准化基地果园4290亩和两个果品加工厂。\n亚丰公司生产的鲜梨包括：鸭梨、秋月梨、皇冠梨、黄金梨、贵妃梨、新梨七号、新高梨、丰水梨等十几个品种，同时，还销售阳光玫瑰、蓝宝石葡萄，胡萝卜、生姜等。亚丰鲜梨连续被评为河北知名品牌、美丽河北·优秀名牌、河北名片、十大林果产品品牌，中国十大梨品牌、中国果业百强品牌、中国国际农产品交易会金奖、京津冀名优果品争霸赛果王、优质产品，不仅成为了华润万家、百果园、中粮集团、阿里巴巴、叮咚买菜、美团等国内大型商超、及生鲜购物平台固定的战略合作伙伴；亚丰公司拥有独立的进出口权,产品还远销美国、加拿大、澳大利亚、新西兰、墨西哥、欧盟、以色列、巴西及东南亚等国家和地区。'},
#  {'exhibitor': 'BRASFLEX Import and ExportBrazilAgent, Exporter, Wholesale/Distributorhttps://www.instagram.com/brasflexbr/',
#   'industry': '',
#   'email': 'mailto:raquel.tavares@brasflexbr.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3J41',
#   'description': 'Brasflex is a Brazilian international trade company specialized in connecting high-quality Brazilian fruits and food products with global markets. We work closely with selected producers to develop export-ready products, ensuring compliance with international standards, market positioning, and reliable supply chains. Our portfolio includes açaí, tropical fruit pulps, frozen fruits, fresh fruits, and other value-added Brazilian food products. Beyond exporting, we help build long-term commercial partnerships by identifying market opportunities, adapting products to customer requirements, and promoting Brazilian agribusiness worldwide through strategic trade missions and international exhibitions.'},
#  {'exhibitor': 'BreedxIsraelOther Serviceshttps://www.breedx.com/',
#   'industry': '',
#   'email': 'mailto:info@breedx.com',
#   'hall': 'Hall3',
#   'booth': 'BoothNo3T07',
#   'description': 'Breedx is a global specialty vegetable development company dedicated to developing, promoting, and commercializing specialty vegetable varieties that deliver unique consumer benefits. We focus on creating high yielding premium products that add value to growers, to retailers and to consumers - driving innovation, quality and sustainability throughout the fresh produce supply chain.\n\n\nBuilding on this commitment, our Pepperito® seedless sweet snack peppers offer a crunchy, healthy snack in vibrant red, yellow, and orange, while our taste tomatoes deliver outstanding balance between natural sweetness and acidity. Both premium varieties proudly won the prestigious ITI Taste Awards, proving that true flavor comes from classic, dedicated breeding.'},
#  ...]

# %%
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                                            exhibitor  \
# 0  2BFresh MicrogreensIsraelExporter, Grower/Prod...
# 1  3 Brothers Agri Export Private Limited3 BROTHE...
# 2  A.P. Moller – Maersk马士基ChinaTransport handling...
# 3  Aartsen Asia LimitedHong Kong, ChinaWholesale/...
# 4  Abdel Wahab Sons Co.EgyptExporterhttp://www.Ab...
#
#                                  industry                              email  \
# 0                                                mailto:avner@taprojects.com
# 1  3 BROTHERS AGRI EXPORT PRIVATE LIMITED      mailto:info@skagriexports.com
# 2                                     马士基     mailto:baylie.zhang@maersk.com
# 3                                               mailto:marketing@aartsen.com
# 4                                          mailto:abdelwahab.fruit@yahoo.com
#
#     hall        booth                                        description  \
# 0  Hall3  BoothNo3S08  2BFRESH is a leading producer of premium micro...
# 1  Hall5  BoothNo5C55  We are among the largest Potato Flakes Manufac...
# 2  Hall5  BoothNo5G01  A.P. Moller - Maersk(Maersk) is an integrated ...
# 3  Hall5  BoothNo5C42  When it comes to fresh, Aartsen goes beyond th...
# 4  Hall3  BoothNo3W30  One of the biggest exporters of fresh citrus i...
#
#                                       description_tc
# 0  2BFRESH 是優質微型蔬菜（Microgreens）及嫩菜（Baby Vegetable...
# 1                                                NaN
# 2  作为一家综合性集装箱物流公司，A.P.穆勒 – 马士基致力于连接和简化我们客户的供应链。作为...
# 3                                                NaN
# 4                                                NaN

# %%
llm = ChatOllama(
        base_url="http://localhost:11434/",
        model="llama3.1:8b",     # Fast 8B parameter model
        temperature=0,          # 0 prevents hallucinations in data extraction
        format="json"           # CRITICAL: Hard enforces valid JSON output
    )

# %%
def gen(string as str):
    full_response=''
    system_instruction = (
        "You are a data transformation engine. Analyze the input data and organize it into a new JSON format. "
        "Your output must be a valid JSON object and nothing else. Do not include markdown code blocks like json. "
        "The output JSON structure MUST match this exact schema format:\n"
        "{\n"
        "  \"exhibitor_name\": \"string\",\n"
        "  \"exhibitor_location\": \"string\",\n"
        "  \"exhibitor_industry\": \"string\",\n"
        "  \"exhibitor_website\": \"url\" \n"
        "}"
    )

    human_query = f"Transform this paragraph: {string}"

    messages = [
        SystemMessage(content=system_instruction),
        HumanMessage(content=human_query)
                ]

    for chunk in llm.stream(messages):
        content = chunk.content
        full_response += content
    
    text=json.loads(full_response)

    return text
# Out:
#   Cell In[93], line 1
#     def gen(string as str):
#                    ^
# SyntaxError: invalid syntax

# %%
full_response=''

system_instruction = (
        "You are a data transformation engine. Analyze the input data and organize it into a new JSON format. "
        "Your output must be a valid JSON object and nothing else. Do not include markdown code blocks like json. "
        "The output JSON structure MUST match this exact schema format:\n"
        "{\n"
        "  \"exhibitor_name\": \"string\",\n"
        "  \"exhibitor_location\": \"string\",\n"
        "  \"exhibitor_industry\": \"string\",\n"
        "  \"exhibitor_website\": \"url\" \n"
        "}"
    )

human_query = f"Transform this paragraph: {df['exhibitor'].iloc[2]}"

messages = [
        SystemMessage(content=system_instruction),
        HumanMessage(content=human_query)
                ]
#llm.stream(messages)

# for chunk in llm.stream(messages):
#     content = chunk.content
#     full_response += content
#     text=json.loads(full_response)

# %%
llm.stream(messages)

for chunk in llm.stream(messages):
    content = chunk.content
    full_response += content

print(full_response)
    # full_response += content
    #text=json.loads(full_response)

# cleaned_response = full_response.strip()
# if cleaned_response.startswith("```"):
#     cleaned_response = cleaned_response.strip("`").removeprefix("json").strip()

#     # 3. Parse JSON AFTER the loop finishes
# text = json.loads(cleaned_response)
# Out:
# {
# {
#   "exhibitor_name": "A.P. Moller – Maersk",
#   "exhibitor_location": "China",
#   "exhibitor_industry": "Transport",
#   "exhibitor_website": "http://www.maersk.com"
# }{
#   "exhibitor_name": "A.P. Moller – Maersk",
#   "exhibitor_location": "China",
#   "exhibitor_industry": "Transport",
#   "exhibitor_website": "http://www.maersk.com"
# }{
#   "exhibitor_name": "A.P. Moller – Maersk",
#   "exhibitor_location": "China",
#   "exhibitor_industry": "Transport",
#   "exhibitor_website": "http://www.maersk.com"
# }

# %%
gen(df['exhibitor'].iloc[2])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 gen(df['exhibitor'].iloc[2])
#
# Cell In[79], line 25, in gen(string)
#      23     content = chunk.content
#      24     full_response += content
# ---> 25     text=json.loads(full_response)
#      27 return text
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 2 column 1 (char 2)

# %%
df['exhibition_detail']=''

for j in range(len(df)):
    df['exhibition_detail']=gen(df['exhibitor'].iloc[j])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[51], line 4
#       1 df['exhibition_detail']=''
#       3 for j in range(len(df)):
# ----> 4     df['exhibition_detail']=gen(df['exhibitor'].iloc[j])
#
# Cell In[49], line 23, in gen(string)
#      21 for chunk in llm.stream(messages):
#      22     content = chunk.content
# ---> 23     full_response += content
#      24     text=json.loads(full_response)
#      26 return text
#
# UnboundLocalError: cannot access local variable 'full_response' where it is not associated with a value

# %%
df.head()
