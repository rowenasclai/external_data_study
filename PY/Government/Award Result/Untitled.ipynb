# %%
import pandas as pd

# %%
import os

os.chdir('/Users/rowena/Other Projects/external_data_study/Result/Government Contract Extraction/gov_cntract/Raw/data')

# %%
df_epd=pd.read_json('gov_epd.json',lines=True)

# %%
df_epd_tmp=df_epd[["ref","department","description","awardee","award_date",	"sum","period","url"]]

# %%
from datetime import datetime

df_epd_tmp['award_date1']=''

for i in range(len(df_epd_tmp)):
    if len(df_epd_tmp.loc[i,'award_date'])==8:
        df_epd_tmp.loc[i,'award_date1']=datetime.strptime(df_epd_tmp.loc[i,'award_date'], "%b %Y")
    elif len(df_epd_tmp.loc[i,'award_date'])>8:
        try:
            df_epd_tmp.loc[i,'award_date1']=datetime.strptime(df_epd_tmp.loc[i,'award_date'], "%B %Y")
        except:
            pass
# Out:
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/1394147320.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_epd_tmp['award_date1']=''

# %%
df_epd_tmp['award_date']=df_epd_tmp['award_date1']
# Out:
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/759014450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_epd_tmp['award_date']=df_epd_tmp['award_date1']

# %%
df_dsd=pd.read_json('gov_dsd.json',lines=True)

# %%
df_dsd.head()
# Out:
#     award_date                                 awardee           start  \
# 0  1 June 2026         REC Engineering Company Limited  14 August 2026
# 1  21 May 2026  Shun Yuen Construction Company Limited     1 June 2026
# 2  27 May 2026  Shun Yuen Construction Company Limited     1 June 2026
# 3  4 June 2026                EGIS-SMEDI Joint Venture    17 June 2026
# 4  27 May 2026     Dunwell Engineering Company Limited    10 June 2026
#
#                end                sum  \
# 0   13 August 2029  HK$270,230,462.00
# 1      31 May 2030  HK$239,233,660.23
# 2      31 May 2030  HK$249,708,314.23
# 3  17 October 2030   HK$28,980,950.00
# 4    4 August 2027    HK$8,900,000.00
#
#                                 project_office                    department  \
# 0                  Sewage Treatment Division 1  Drainage Services Department
# 1               Hong Kong and Islands Division  Drainage Services Department
# 2                      Mainland North Division  Drainage Services Department
# 3                     Cavern Projects Division  Drainage Services Department
# 4  Electrical and Mechanical Projects Division  Drainage Services Department
#
#           type                                                url  \
# 0     Contract  https://www.dsd.gov.hk/EN/Our_Projects/Contrac...
# 1     Contract  https://www.dsd.gov.hk/EN/Our_Projects/Contrac...
# 2     Contract  https://www.dsd.gov.hk/EN/Our_Projects/Contrac...
# 3     Contract  https://www.dsd.gov.hk/EN/Our_Projects/Contrac...
# 4  Consultancy  https://www.dsd.gov.hk/EN/Our_Projects/Contrac...
#
#                ref
# 0       DE/2026/08
# 1       DC/2026/02
# 2       DE/2026/05
# 3       DC/2025/10
# 4  CE 38/2025 (SP)

# %%
df_dsd_tmp=df_dsd[["ref","department","description","awardee","award_date",	"sum","period","url","start","end"]]

# %%
df_dsd_tmp['award_date1']=''

for i in range(len(df_dsd_tmp)):
    df_dsd_tmp.loc[i,'award_date1']=datetime.strptime(df_dsd_tmp.loc[i,'award_date'], "%d %B %Y")
    df_dsd_tmp.loc[i,'start1']=datetime.strptime(df_dsd_tmp.loc[i,'start'], "%d %B %Y")
    df_dsd_tmp.loc[i,'end1']=datetime.strptime(df_dsd_tmp.loc[i,'end'], "%d %B %Y")
# Out:
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/2585314945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dsd_tmp['award_date1']=''

# %%
df_dsd_tmp['award_date']=df_dsd_tmp['award_date1']
df_dsd_tmp['start']=df_dsd_tmp['start1']
df_dsd_tmp['end']=df_dsd_tmp['end1']

# %%
df_dsd_tmp=df_dsd_tmp[["ref","department","description","awardee","award_date",	"sum","period","url","start","end"]]

# %%
df_cedd=pd.read_json('gov_cedd.json',lines=True)

# %%
df_cedd_tmp=df_cedd[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url"#,"start","end"
                    ]]

# %%
df_cedd_tmp['award_date1']=''

for i in range(len(df_cedd_tmp)):
    df_cedd_tmp.loc[i,'award_date1']=datetime.strptime(df_cedd_tmp.loc[i,'award_date'], "%d/%m/%Y")

df_cedd_tmp['award_date']=df_cedd_tmp['award_date1']
# Out:
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/2605515332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cedd_tmp['award_date1']=''
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/2605515332.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cedd_tmp['award_date']=df_cedd_tmp['award_date1']

# %%
df_cedd_tmp=df_cedd_tmp[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url"#,"start","end"
                    ]]

# %%
df_cedd_tmp.head()
# Out:
#                              ref  \
# 0       Contract No.: CV/2025/02
# 1  Contract No.: CEDD/S/T/1/2026
# 2       Contract No.: ND/2024/11
# 3       Contract No.: GE/2025/29
# 4       Contract No.: YL/2024/03
#
#                                      department  \
# 0  Civil Engineering and Development Department
# 1  Civil Engineering and Development Department
# 2  Civil Engineering and Development Department
# 3  Civil Engineering and Development Department
# 4  Civil Engineering and Development Department
#
#                                          description  \
# 0  Landslip Prevention and Mitigation Programme, ...
# 1  Landslip Prevention and Mitigation Programme, ...
# 2  Landslip Prevention and Mitigation Programme, ...
# 3  Tung Chung New Town Extension – Infrastructure...
# 4  San Tin Technopole Phase 1 Stage 1 (East) – Co...
#
#                          awardee           award_date             sum  \
# 0         CM Geotechnics Limited  2026-07-29 00:00:00       HK$270.64
# 1   Pan Kee Construction Limited  2026-07-14 00:00:00       HK$193.17
# 2       Tysan Foundation Limited  2026-07-06 00:00:00        HK$32.03
# 3  CCC-CCECC-CR11G Joint Venture  2026-06-26 00:00:00  HK$792 million
# 4    CRBC - MAYLON Joint Venture  2026-06-11 00:00:00    HK$ 2,266.91
#
#                                                  url
# 0  https://www.cedd.gov.hk//eng/tender-notices/co...
# 1  https://www.cedd.gov.hk//eng/tender-notices/co...
# 2  https://www.cedd.gov.hk//eng/tender-notices/co...
# 3  https://www.cedd.gov.hk//eng/tender-notices/co...
# 4  https://www.cedd.gov.hk//eng/tender-notices/co...

# %%
df_cedd_consultant=pd.read_json('gov_cedd_consultant.json',lines=True)

# %%
df_cedd_consultant_tmp=df_cedd_consultant[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url","start","end"
                    ]]

# %%
df_cedd_consultant_tmp['award_date1']=''
df_cedd_consultant_tmp['start1']=''
df_cedd_consultant_tmp['end1']=''

for i in range(len(df_cedd_consultant_tmp)):
    df_cedd_consultant_tmp.loc[i,'award_date1']=datetime.strptime(df_cedd_consultant_tmp.loc[i,'award_date'], "%d/%m/%Y")
    df_cedd_consultant_tmp.loc[i,'start1']=datetime.strptime(df_cedd_consultant_tmp.loc[i,'start'], "%d/%m/%Y")
    df_cedd_consultant_tmp.loc[i,'end1']=datetime.strptime(df_cedd_consultant_tmp.loc[i,'end'], "%d/%m/%Y")


df_cedd_consultant_tmp['award_date']=df_cedd_consultant_tmp['award_date1']
df_cedd_consultant_tmp['start']=df_cedd_consultant_tmp['start1']
df_cedd_consultant_tmp['end']=df_cedd_consultant_tmp['end1']

# %%
df_cedd_consultant_tmp=df_cedd_consultant_tmp[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url","start","end"
                    ]]

# %%
df_cedd_consultant_tmp.head()
# Out:
#                ref                                    department  \
# 0  CE 16/2026 (CE)  Civil Engineering and Development Department
# 1   CE 1/2026 (CE)  Civil Engineering and Development Department
# 2  CE 39/2025 (CE)  Civil Engineering and Development Department
# 3  CE 18/2025 (GE)  Civil Engineering and Development Department
# 4  CE 19/2025 (GE)  Civil Engineering and Development Department
#
#                                          description  \
# 0  Hung Shui Kiu/Ha Tsuen New Development Area Re...
# 1  The Establishment of an Agricultural Park (Pha...
# 2  Reclamation at Lung Kwu Tan - Design and Const...
# 3  Landslip Prevention and Mitigation Programme, ...
# 4  Landslip Prevention and Mitigation Programme, ...
#
#                                  awardee           award_date  \
# 0        Arup-AtkinsRéalis Joint Venture  2026-08-06 00:00:00
# 1       Mott MacDonald Hong Kong Limited  2026-07-13 00:00:00
# 2  Ove Arup & Partners Hong Kong Limited  2026-06-25 00:00:00
# 3  Asia Infrastructure Solutions Limited  2026-03-20 00:00:00
# 4             AECOM Asia Company Limited  2026-03-20 00:00:00
#
#                  sum                                                url  \
# 0  HK$148,000,002.00  https://www.cedd.gov.hk/eng/tender-notices/con...
# 1   HK$14,980,000.00  https://www.cedd.gov.hk/eng/tender-notices/con...
# 2   HK$43,500,000.00  https://www.cedd.gov.hk/eng/tender-notices/con...
# 3   HK$25,500,000.00  https://www.cedd.gov.hk/eng/tender-notices/con...
# 4   HK$24,600,000.00  https://www.cedd.gov.hk/eng/tender-notices/con...
#
#                  start                  end
# 0  2026-08-10 00:00:00  2039-08-31 00:00:00
# 1  2026-07-17 00:00:00  2034-09-17 00:00:00
# 2  2026-06-30 00:00:00  2036-06-29 00:00:00
# 3  2026-03-31 00:00:00  2032-03-30 00:00:00
# 4  2026-03-31 00:00:00  2031-03-30 00:00:00

# %%
df_emsd=pd.read_json('gov_emsd.json',lines=True)

# %%
df_emsd_tmp=df_emsd[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url",#"start",
                                "end"
                    ]]

# %%
df_emsd_tmp.head()
# Out:
#                ref department  \
# 0  CE 40/2025 (CE)       emsd
# 1  CE 39/2024 (EM)       emsd
# 2  CE 55/2023 (EM)       emsd
# 3  CE 21/2023 (CE)       emsd
# 4  CE 28/2023 (EM)       emsd
#
#                                          description  \
# 0  Development of Intelligent Solutions for Smart...
# 1  Monitoring of Electricity Supply Companies and...
# 2  Replacement of High Voltage, Low Voltage and G...
# 3  The District Cooling System (DCS) for Hung Shu...
# 4  Replacement of Tunnel Lighting System at Tate'...
#
#                                  awardee       award_date               sum  \
# 0  Asia Infrastructure Solutions Limited    27 March 2026  HK$23,800,000.00
# 1              AtkinsRealis Asia Limited  27 January 2026  HK$11,030,991.00
# 2          Pypun-KD & Associates Limited  5 December 2024   HK$7,380,000.00
# 3              Binnies Hong Kong Limited     18 June 2024  HK$50,000,000.00
# 4                     WSP (Asia) Limited      13 May 2024   HK$4,828,800.00
#
#                                                  url               end
# 0  /filemanager/en/content_880/CE40_2025_CE-Inter...      7 April 2028
# 1  /filemanager/en/content_880/CE39_2024_EM-Inter...  10 February 2030
# 2  /filemanager/en/content_409/EOI_Invitation_Let...  18 December 2028
# 3  /filemanager/en/content_409/CE21_2023(CE)_Noti...  31 December 2033
# 4  /filemanager/en/content_409/EOI_Invitation Let...       27 May 2028

# %%
df_emsd_tmp['award_date1']=''
df_emsd_tmp['end1']=''

for i in range(len(df_cedd_consultant_tmp)):
    df_emsd_tmp.loc[i,'award_date1']=datetime.strptime(df_emsd_tmp.loc[i,'award_date'], "%d %B %Y")
    df_emsd_tmp.loc[i,'end1']=datetime.strptime(df_emsd_tmp.loc[i,'end'], "%d %B %Y")


df_emsd_tmp['award_date']=df_emsd_tmp['award_date1']
df_emsd_tmp['end']=df_emsd_tmp['end1']

# %%
df_emsd_tmp=df_emsd_tmp[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url",#"start",
                                "end"
                    ]]

# %%
df_emsd_construction=pd.read_json('gov_emsd_construction.json',lines=True)

# %%
df_emsd_construction_tmp=df_emsd_construction[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url"#,"start","end"
                    ]]

# %%
df_emsd_construction_tmp.head()
# Out:
#              ref                                     department  \
# 0      1280EM25T  Electrical and Mechanical Services Department
# 1      1212EM25W  Electrical and Mechanical Services Department
# 2  ADM/T/2025/02  Electrical and Mechanical Services Department
# 3      1766EM24T  Electrical and Mechanical Services Department
# 4      1960EM25T  Electrical and Mechanical Services Department
#
#                                          description  \
# 0  Triennial Term Contract for the Comprehensive ...
# 1  Enhancement Works for Tunnel Ventilation Fans ...
# 2  Provision of Property Management Services to t...
# 3  Quinquennial Term Contract for Air-Conditionin...
# 4  Quadrennial Term Contract for Repairs, Operati...
#
#                                              awardee award_date  \
# 0                     Holake Hong Kong Lifts Limited   May 2026
# 1        The Jardine Engineering Corporation Limited   May 2026
# 2               Synergis Facility Management Limited   Apr 2026
# 3  Winston Air Conditioning & Engineering (Hong K...   Apr 2026
# 4   Kwong Hing Loong Engine & Boiler Factory Limited   Apr 2026
#
#                                                  sum  \
# 0                     Holake Hong Kong Lifts Limited
# 1        The Jardine Engineering Corporation Limited
# 2               Synergis Facility Management Limited
# 3  Winston Air Conditioning & Engineering (Hong K...
# 4   Kwong Hing Loong Engine & Boiler Factory Limited
#
#                                                  url
# 0  https://www.emsd.gov.hk/en/tenders_contracts_a...
# 1  https://www.emsd.gov.hk/en/tenders_contracts_a...
# 2  https://www.emsd.gov.hk/en/tenders_contracts_a...
# 3  https://www.emsd.gov.hk/en/tenders_contracts_a...
# 4  https://www.emsd.gov.hk/en/tenders_contracts_a...

# %%
df_emsd_construction_tmp['award_date1']=''

for i in range(len(df_cedd_consultant_tmp)):
    df_emsd_construction_tmp.loc[i,'award_date1']=datetime.strptime(df_emsd_construction_tmp.loc[i,'award_date'], "%b %Y")


df_emsd_construction_tmp['award_date']=df_emsd_construction_tmp['award_date1']
# Out:
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/500775801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emsd_construction_tmp['award_date1']=''
# /var/folders/cc/fgdvcyz155z2b_s9qh66r2pw0000gn/T/ipykernel_2015/500775801.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emsd_construction_tmp['award_date']=df_emsd_construction_tmp['award_date1']

# %%
df_emsd_construction_tmp=df_emsd_construction_tmp[["ref","department","description","awardee","award_date",	"sum",#"period",
                     "url"#,"start","end"
                    ]]

# %%
with open('gov_hkaa.json', 'r', encoding='utf-8') as file:
    df_hkaa = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[349], line 2
#       1 with open('gov_hkaa.json', 'r', encoding='utf-8') as file:
# ----> 2     df_hkaa = json.load(file)
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 569)
