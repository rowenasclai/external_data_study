# %%
import pdfplumber
import pandas as pd
import requests
import io
import re
import os

import camelot.io as camelot
# Out:
# /opt/anaconda3/envs/playwright_env/lib/python3.10/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
settings = {
    "explicit_vertical_lines": [ 10,410, 530, 690,810 ],
    "explicit_horizontal_lines": [ 180,210, 290,380,470,580],
    "horizontal_strategy": "lines", 
    "snap_tolerance": 3,
    "join_tolerance": 5
}

with pdfplumber.open("BP_Tender_Award_Jan_2026.pdf") as pdf:
    page = pdf.pages[0]
    # Apply the custom settings
    table = page.extract_table(table_settings=settings)
#table = page[0].extract_table(table_settings=settings)

# %%
tmp=pd.DataFrame(table,columns=table[0])

# %%
settings = {
    "explicit_vertical_lines": [ 10,410, 530, 690,810 ],
    "explicit_horizontal_lines": [ 20,80,170, 250,340,420,580],
    "horizontal_strategy": "lines", 
    "snap_tolerance": 3,
    "join_tolerance": 5
}

all_data = table

with pdfplumber.open("BP_Tender_Award_Jan_2026.pdf") as pdf:
    page = pdf.pages[1]
    # Apply the custom settings
    table = page.extract_table(table_settings=settings)
    tmp1=pd.DataFrame(table,columns=table[0])
    tmp=pd.concat([tmp, tmp1])
        #all_data.append(table)

# %%
settings = {
    "explicit_vertical_lines": [ 10,410, 530, 690,810 ],
    "explicit_horizontal_lines": [ 60,90,190, 300,390,580],
    "horizontal_strategy": "lines", 
    "snap_tolerance": 3,
    "join_tolerance": 5
}

all_data = table

with pdfplumber.open("BP_Tender_Award_Jan_2026.pdf") as pdf:
    page = pdf.pages[2]
    # Apply the custom settings
    table = page.extract_table(table_settings=settings)
    tmp1=pd.DataFrame(table,columns=table[0])
    tmp=pd.concat([tmp, tmp1])
        #all_data.append(table)

# %%
settings = {
    "explicit_vertical_lines": [ 10,410, 530, 690,810 ],
    "explicit_horizontal_lines": [ 20,80,170, 280,390,480,580],
    "horizontal_strategy": "lines", 
    "snap_tolerance": 3,
    "join_tolerance": 5
}

all_data = table

with pdfplumber.open("BP_Tender_Award_Jan_2026.pdf") as pdf:
    page = pdf.pages[4]
    # Apply the custom settings
    table = page.extract_table(table_settings=settings)
    tmp1=pd.DataFrame(table,columns=table[0])
    tmp=pd.concat([tmp, tmp1])
        #all_data.append(table)

# %%
tmp
# Out:
#                                     Name of Contract  \
# 0                                   Name of Contract
# 1  Construction of Public Housing Development at ...
# 2  Construction of Public Housing Development at ...
# 3  Construction of Public Housing Development at ...
# 4  Construction of Public Housing Development at ...
# 0                                   Name of Contract
# 1  Soft Landscape Works for Public Housing Develo...
# 2  Soft Landscape Works for Public Housing Develo...
# 3  Soft Landscape Works for Public Housing Develo...
# 4  Provision of Hospitalisation and Maternity Ins...
# 5  Design, Supply, Delivery, Installation, Commis...
# 0                                   Name of Contract
# 1  District Term Contract for the Maintenance, Im...
# 2  District Term Contract for the Maintenance, Im...
# 3  Redecoration of Choi Yuen Estate and Tai Yuen ...
# 4  Redecoration of Yau Oi Estate and Sam Shing Es...
# 0                                   Name of Contract
# 1  Operation and Maintenance of Automated Refuse ...
# 2  Property Management Agency Contract for Kai Yi...
# 3  Property Management Agency Contract for Kam Pa...
# 4  Property Services Contract (PMA Mode) for Quee...
# 5  Property Services Contract (PMA Mode) for Un C...
# 0                                   Name of Contract
# 1  Property Services Contract (PMA Mode) for Kwu ...
# 2  Property Services Contract (PMA Mode) for Fung...
# 3  For Horticulture, Cleansing and Security Servi...
# 4                             Date: 27 February 2026
# 5
#
#                                 Tendering\nProcedure  \
# 0                               Tendering\nProcedure
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 0                               Tendering\nProcedure
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                               Open
# 5                                               Open
# 0                               Tendering\nProcedure
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 0                               Tendering\nProcedure
# 1                                               Open
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 5                                          Selective
# 0                               Tendering\nProcedure
# 1                                          Selective
# 2                                          Selective
# 3  d in undertaking Housing\nable in the website ...
# 4
# 5
#
#                         Contractor(s) &\nAddress(es)  \
# 0                       Contractor(s) &\nAddress(es)
# 1  Shui On Building Contractors\nLimited\n34/F., ...
# 2  Woon Lee Construction\nCompany Limited\n8/F, E...
# 3  Shui On Building Contractors\nLimited\n34/F., ...
# 4  Unistress Building\nConstruction Limited\n10/F...
# 0                       Contractor(s) &\nAddress(es)
# 1  Asia Landscaping Limited\nFlat A & C, 4/F, Int...
# 2  Tsui Yuen Garden\nFlat B, 8/F, Block 3,\nSheun...
# 3  Tsui Yuen Garden\nFlat B, 8/F, Block 3,\nSheun...
# 4  Assicurazioni Generali\nSocieta Per Azioni\n21...
# 5  ELM Computer Technologies\nLimited\nUnit 1201-...
# 0                       Contractor(s) &\nAddress(es)
# 1  Cheung Hing Construction\nCompany Limited\nUni...
# 2  Hop Lee Builders Company\nLimited\n12/F, Comwe...
# 3  K-Peak Company Limited\nUnit 1, 12/F,\nLee Sum...
# 4  Sun On Engineering Company\nLimited\n13/F, Woo...
# 0                       Contractor(s) &\nAddress(es)
# 1  Envac Far East Limited\nUnit 508, 5/F,\nBuildi...
# 2  Creative Property Services\nConsultants Limite...
# 3  Creative Property Services\nConsultants Limite...
# 4  China Overseas Property\nServices Limited\n19/...
# 5  Unimax Property Consultancy\nLimited\nFlat C, ...
# 0                       Contractor(s) &\nAddress(es)
# 1  China Overseas Property\nServices Limited\n19/...
# 2  Funing Property Management\nLimited\nFlat D, 1...
# 3  Authority contracts, they are required\n//comi...
# 4
# 5
#
#                    Amount(HK$)/\nContract Award Date
# 0                  Amount(HK$)/\nContract Award Date
# 1                   1,448,000,000.00\n7 January 2026
# 2                   2,365,042,000.00\n2 January 2026
# 3                  1,636,000,000.00\n20 January 2026
# 4                  1,125,000,000.00\n29 January 2026
# 0                  Amount(HK$)/\nContract Award Date
# 1                       2,000,000.00\n9 January 2026
# 2                      1,304,615.40\n26 January 2026
# 3                      3,323,444.20\n29 January 2026
# 4                        183,656.00\n19 January 2026
# 5                      8,100,000.00\n26 January 2026
# 0                  Amount(HK$)/\nContract Award Date
# 1                    391,477,840.00\n28 January 2026
# 2                    714,280,980.00\n20 January 2026
# 3                     52,339,535.00\n12 January 2026
# 4                     68,311,945.00\n29 January 2026
# 0                  Amount(HK$)/\nContract Award Date
# 1                      9,900,000.00\n27 January 2026
# 2                      27,724,737.04\n9 January 2026
# 3                      30,531,555.72\n8 January 2026
# 4                    119,635,251.76\n22 January 2026
# 5                    240,350,656.39\n22 January 2026
# 0                  Amount(HK$)/\nContract Award Date
# 1                    135,352,973.75\n22 January 2026
# 2                    158,797,949.82\n22 January 2026
# 3  to apply for admission to\neng/procurement_2.j...
# 4
# 5

# %%
export_ha=tmp.replace('\n',' ', regex=True)

export_ha=export_ha[export_ha['Name of Contract'].str.strip()!='Name of Contract']

# %%
export_ha.columns=export_ha.columns.str.replace('\n',' ', regex=True)

# %%
export_ha
# Out:
#                                     Name of Contract  \
# 1  Construction of Public Housing Development at ...
# 2  Construction of Public Housing Development at ...
# 3  Construction of Public Housing Development at ...
# 4  Construction of Public Housing Development at ...
# 1  Soft Landscape Works for Public Housing Develo...
# 2  Soft Landscape Works for Public Housing Develo...
# 3  Soft Landscape Works for Public Housing Develo...
# 4  Provision of Hospitalisation and Maternity Ins...
# 5  Design, Supply, Delivery, Installation, Commis...
# 1  District Term Contract for the Maintenance, Im...
# 2  District Term Contract for the Maintenance, Im...
# 3  Redecoration of Choi Yuen Estate and Tai Yuen ...
# 4  Redecoration of Yau Oi Estate and Sam Shing Es...
# 1  Operation and Maintenance of Automated Refuse ...
# 2  Property Management Agency Contract for Kai Yi...
# 3  Property Management Agency Contract for Kam Pa...
# 4  Property Services Contract (PMA Mode) for Quee...
# 5  Property Services Contract (PMA Mode) for Un C...
# 1  Property Services Contract (PMA Mode) for Kwu ...
# 2  Property Services Contract (PMA Mode) for Fung...
# 3  For Horticulture, Cleansing and Security Servi...
# 4                             Date: 27 February 2026
# 5
#
#                                  Tendering Procedure  \
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                               Open
# 5                                               Open
# 1                                          Selective
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 1                                               Open
# 2                                          Selective
# 3                                          Selective
# 4                                          Selective
# 5                                          Selective
# 1                                          Selective
# 2                                          Selective
# 3  d in undertaking Housing able in the website a...
# 4
# 5
#
#                          Contractor(s) & Address(es)  \
# 1  Shui On Building Contractors Limited 34/F., Sh...
# 2  Woon Lee Construction Company Limited 8/F, Ent...
# 3  Shui On Building Contractors Limited 34/F., Sh...
# 4  Unistress Building Construction Limited 10/F, ...
# 1  Asia Landscaping Limited Flat A & C, 4/F, Inte...
# 2  Tsui Yuen Garden Flat B, 8/F, Block 3, Sheung ...
# 3  Tsui Yuen Garden Flat B, 8/F, Block 3, Sheung ...
# 4  Assicurazioni Generali Societa Per Azioni 21/F...
# 5  ELM Computer Technologies Limited Unit 1201-07...
# 1  Cheung Hing Construction Company Limited Unit ...
# 2  Hop Lee Builders Company Limited 12/F, Comweb ...
# 3  K-Peak Company Limited Unit 1, 12/F, Lee Sum F...
# 4  Sun On Engineering Company Limited 13/F, Woon ...
# 1  Envac Far East Limited Unit 508, 5/F, Building...
# 2  Creative Property Services Consultants Limited...
# 3  Creative Property Services Consultants Limited...
# 4  China Overseas Property Services Limited 19/F,...
# 5  Unimax Property Consultancy Limited Flat C, 4/...
# 1  China Overseas Property Services Limited 19/F,...
# 2  Funing Property Management Limited Flat D, 11/...
# 3  Authority contracts, they are required //comis...
# 4
# 5
#
#                     Amount(HK$)/ Contract Award Date
# 1                    1,448,000,000.00 7 January 2026
# 2                    2,365,042,000.00 2 January 2026
# 3                   1,636,000,000.00 20 January 2026
# 4                   1,125,000,000.00 29 January 2026
# 1                        2,000,000.00 9 January 2026
# 2                       1,304,615.40 26 January 2026
# 3                       3,323,444.20 29 January 2026
# 4                         183,656.00 19 January 2026
# 5                       8,100,000.00 26 January 2026
# 1                     391,477,840.00 28 January 2026
# 2                     714,280,980.00 20 January 2026
# 3                      52,339,535.00 12 January 2026
# 4                      68,311,945.00 29 January 2026
# 1                       9,900,000.00 27 January 2026
# 2                       27,724,737.04 9 January 2026
# 3                       30,531,555.72 8 January 2026
# 4                     119,635,251.76 22 January 2026
# 5                     240,350,656.39 22 January 2026
# 1                     135,352,973.75 22 January 2026
# 2                     158,797,949.82 22 January 2026
# 3  to apply for admission to eng/procurement_2.jsp".
# 4
# 5

# %%
for i in range(len(export_ha)):
    try:
        export_ha.loc[i,'Contractor(s)']=export_ha['Contractor(s) & Address(es)'][i][:export_ha['Contractor(s) & Address(es)'][i].index('Limited')+7].strip()
        export_ha.loc[i,'Address(es)'][i]=export_ha['Contractor(s) & Address(es)'][i][export_ha['Contractor(s) & Address(es)'][i].index('Limited')+7:].strip()
        export_ha.loc[i,'Amount(HK$)']=export_ha['Amount(HK$)/ Contract Award Date'][i][:re.search(r'(\d+)\s(\d+)', export_ha['Amount(HK$)/ Contract Award Date'][0]).start()+2].strip()
        export_ha.loc[i,'Contract Award Date']=export_ha['Amount(HK$)/ Contract Award Date'][i][re.search(r'(\d+)\s(\d+)', export_ha['Amount(HK$)/ Contract Award Date'][0]).start()+2:].strip()

        #export_ha['Amount']=export_ha
    except:
        pass

# %%
export_ha=export_ha.reset_index()

# %%
export_ha = export_ha.drop(['level_0','index'], axis=1)

# %%
export_ha.to_csv('/Users/rowena/Other Projects/external_data_study/Result/HA/ha_Jan2026.csv', index=False, encoding="utf-8")

# %%
import pdfplumber
pdf = pdfplumber.open("BP_Tender_Award_Jan_2026.pdf") # See note below
page = pdf.pages[4]
im = page.to_image()

im.debug_tablefinder({
    "explicit_vertical_lines": [ 10,410, 530, 690,810 ],
    "explicit_horizontal_lines": [ 20,80,170, 280,390,480,580],
    "horizontal_strategy": "lines", 
    "snap_tolerance": 3,
    "join_tolerance": 5
})
